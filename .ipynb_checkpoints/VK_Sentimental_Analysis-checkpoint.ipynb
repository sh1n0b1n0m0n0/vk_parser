# %%
from webapp import create_app
from vk_parser import *
import re


def preprocess_text(text):
    text = text.lower().replace("ё", "е")
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', text)
    text = re.sub('@[^\s]+', 'USER', text)
    text = re.sub('[^a-zA-Zа-яА-Я1-9]+', ' ', text)
    text = re.sub(' +', ' ', text)
    return text.strip()


app = create_app()
with app.app_context():
    query = Comment.query.all()
    preprop_comm = []

    for comment in query:
        preprop_comm.append(preprocess_text(comment.comment_text))

# %%
preprop_comm
# Out:
# ['забавно',
#  '',
#  'гмо качки что тут скажешь жили люди своей жизнью никого не трогали и все у них было хорошо',
#  'вернувшись в реальный мир и осознав что ваданглоу оказался не более чем ложью великого океана в смысле ложью люди воскресали воскресали людям было норм норм где тут варповские ложь и обман вот надо было обязательно все сломать',
#  'а про этот случай есть рассказ или книга',
#  'а клинки то стоило прихватить с собой',
#  'i never asked for this',
#  'класс очень крутые арты',
#  'это фанфик',
#  'у фон раукова и тодбрингера головные уборы заметно скромнее чем в оригинале',
#  'а чо так можно было',
#  'мне нравится его стиль сейчас мало кто так рисует',
#  'вампир это рандомный дракон или сам абхораш',
#  'там мы узнаем что жиллиман в 41к это альфарий',
#  'меч в голове гидры',
#  'я думал книга про альфария будет последней',
#  'какой мужчина',
#  'будем почитать',
#  'это же не слухи майк брукс у себя в твиттере об этом писал и бл тоже',
#  'и на всех страницах будет написано мелким почерком я альфарий',
#  'стрелок что ты тут делаешь',
#  '',
#  'я думал роб сандерс писать будет у него про гидру много чего было',
#  'сталкердоминатус',
#  'ох только бы альфария не слили как пертурабо',
#  'после 1 легиона будет 2 потрясающий ход',
#  'после такого the first of the fallen где толком мало что раскрыли ожидания о новой книге не внушают оптимизма линия альфария завершена нам расскажут что омегон сделал с данными гено кузней что украл у коракса вопросы без ответов',
#  'а нельзя определить из какого ордена космодес на третьем пикте',
#  '',
#  'спойлер будет как в кампании вигилуса то есть ничего не поменяется и хаоситам максимум дадут пару тактических побед а потом обоссут',
#  'о неплохо еще бы малериона подвезли в аос',
#  'вангую нанеся тяжелейший урон тифус отступает империум потерял over9 единиц техники и солдат миры кроме самого важного превращены в руины на оставшемся же идет вялотекущий махач пару раз произойдут чудеса веры сороритас в рукопашку будут рвать чумной десант где ж такое было то где',
#  '',
#  'отличный анонс если уровень качества и общей проработки сюжета будет сравним с вигилус в огне то получится отличный кампейн опасение только одно чтобы концовка не была в духе один из умнейших командиров калгар решился самоубиться об абаддона не имея запасного плана',
#  'круть хаоситов подвезли',
#  'зачетная шмаровозка сигвальд знает как передвигаться по смертным мирам стильно',
#  'лучший вернулся великолепно',
#  'красота пришла в ваху наконец то',
#  'о зигвальду походу понравился золотой дождь еще хочет',
#  'но где слаанеш',
#  'как будто не официальная минька а конверсия ладно хоть рожа теперь не такая ублюдочная как раньше',
#  'вот самое место вашему сигвальду',
#  'ну шо тут скажешь',
#  'а тифусу хоть раз кто нибудь лицо ломал или он непобежденным ходит',
#  'разве его не сожрал трогг',
#  'кустодес теперь в аосе что там с ним в конце времен стало',
#  'да он лучше фульгрима от форджи хотя все лучше фули от форджи',
#  'так секундочку они забрали рапиру у сангвиния',
#  'зигвальд прибывает в рейкланд пикт в цвете',
#  'ну мои деньги уже летят в монитор прекратите',
#  '',
#  'это тип гедонистам отсыпят а то я не в курсе последних событий ну я знаю что куплю если начну в аос',
#  'погодите слаанеш воскресила сигвальда в age of sigmar',
#  'да екарный бабай тэтухов уже стопицот раз обновляли где светлый эльдарчеги лордов фениксов хз сколько лет не обновляли до сих пор карланы',
#  'ну тут надо еще руки доделывать это дорого и лень',
#  'как раз релиз слаанеш в аосе вжарить сразу в обе вселенные if u know what i meeeeean',
#  'у кустокавилла появился достойный соперник',
#  'иди своей дорогой сталкер',
#  'я оплачиваю вот этим прекрасным павучком свое право украсть это себе на аву',
#  'а сколько всего оф минек примархов re душевно ребят',
#  'я слышал тут у вас примарх достойный появился',
#  'а еще две руки где',
#  'великолепный',
#  'ну все ждем релиза детишек в 4 к',
#  'так он же умер нет',
#  'а еще из него можно сделать сангвиния',
#  'это рофл',
#  'у фулгрима есть крылья',
#  'а с каких пор тифус на побегушках у абы',
#  'слишком мало рук',
#  'второй пары рук нет',
#  'верните примархам нормальные правила магнус уже устал деградировать',
#  'вот и супер секретный кодекс ксеносов а не какой то там анерис',
#  'кстати а что с ним он жив',
#  'и почему мне это напомнило сержермена из скитальцев',
#  'в итоге все ложь п деж и провокация',
#  'можно ли считать теперь фулгрима фурри',
#  'его разве огр не обоссал',
#  'у кого есть ссылка на книги про примархов хочу прочитать за ранее спасибо',
#  'это кто поясните',
#  'ну или не про альфария вообще уверен что гв не станут менять статус альфария поэтому конкретики не будет а нам нужны факты факты',
#  'девочки держитесь да тут всем напрячься надо',
#  '',
#  'фанарт',
#  'если он наклонит голову и решит посмотреть себе под ноги он увидит только свой горжет wtf',
#  'збс первый норм арт сантара может еще амадея покажут',
#  'звоню каэрсону',
#  'фотка трогга',
#  'сантар по книгам вафля тупая какая то отсосал просто у всех детишек как его ток не пинали хотя он мог убить капитана детей изи просто затупок папкин походу все жч тупорылые железяки',
#  'весело в аосе один бычок или бычиха чего стоит',
#  'ждем батлфорс',
#  'не очень шарю в аосии поясните это типа высшие эльфы или кто почему у мужика с косичкой есть два шара и один красный',
#  'вспоминается шоу маст шоу он песня с рисованным мультом на тему вахи санта барбара какая то уже выходит война которая без результата лучше бы не знаю ввели прехереси громовых и что было до них истребление их же про потеряшек и завоевание терры ну и как импи дошел вообще до жизни такой не знаю ваха как то очень скучна и предсказуема последние годы',
#  'все ясно автор поклонник кончиты вюрст',
#  'опять тифус сколько можно его пропихивать уже во всякик вселенские заварушки',
#  'зигвальд похож на порченого сангвиния',
#  'чумные десантники захватить миры кузни может все таки уничтожить',
#  'жаль что не к 4 к',
#  'бедные космоволки',
#  'да настанет день искупления',
#  'flashgitz продолжает уничтожать фурей',
#  '',
#  'не дай ксеносу жить',
#  'один поимел второго и появились космо псы',
#  'ого первые пикты с рангданских ксеноцидов',
#  'идут годы а одинокий нойзмарин грустно играет на гитаре',
#  'с такой ереси охренел бы даже фабий',
#  '',
#  'на третьем арте вижу инвока из доты 2',
#  'что то не пойму как они чародеев прикончили если они постоянно респаунятся',
#  'классик',
#  'сначала подумал что это гомозек',
#  '',
#  'вау ему штаны подарили',
#  'это конверсия или фотошоп выглядит потрясно',
#  'чуть уколоть сдуется космодетка',
#  'спасибо за пост',
#  'так просто покрасьте его под фулгрима лол',
#  'пипец текста не буду читать',
#  'да не волки а их волки',
#  'люди фурри кста',
#  'чет фуля не похож на дп он как будто договорился с лаэр на несколько операций',
#  'да это буквально невероятные кустодии',
#  'че там по мете аоса гей эльфы из далекого хиша все еще гнут на 2',
#  'ну хватит если его сделают жиллиман тут же закончится и кому империум защищать',
#  '',
#  'а кто таков',
#  'это которому каэсорон пах пиломечом распилил',
#  'ууу отправить гнилого урода захватить ценные кузницы как это правильно',
#  'строить города закатать дорна в фундамент хорошая мечта',
#  'ты любишь эти игрушки да а теперь сломай каждую десятую',
#  'классный анекдот',
#  'классный арт',
#  'нифига он огромный у него целый гвардеец в руке помещается',
#  'он его потом съест',
#  'пертурабо был хорошим если бы его не посылали в ад и не игнорировали а есши бы еще он вырос из маленького мальчика и не обижался на всех батя же его предупреждал о том что он впадет в ересь а он так и не послушал его возможно он был лучше дорна однако он проиграл дорн факел надежды и ярко светит а пертурабо маленькая свеча надежды хотя может батя и планировал что часть его легионов уйдет и восстанет против него черт его знает',
#  'жесть круть',
#  'если у него реально есть такая приемная дочь то к пертурабо я стану относиться в разы лучше',
#  'какой то намек на комбэк пертурабы',
#  'игрушки гвардейца из 4 к и кукла сестры битвы какой то альтернативный пертурабо',
#  'а сейчас маленький человек я расскажу тебе историю как я расхерачил свой родной мир олимпию ах никто ведь не понимает что я просто хотел спокойствия',
#  'хотел спокойной жизни но вместо суши и роллов заказал своим децимацию',
#  '',
#  'а где соплеотвод',
#  'лепили зверей из пластилина у ребенка случайно получилось лучше чем у пепе с тех пор пластилин в доме под запретом',
#  '',
#  'пертурабо был особо вменяемым икона прогресса транс гуманизма он строил города театры стадионы делал открытия в медицине мастер не хуже вулкана это чудовищно заставлять художника заниматься грязной работой',
#  'император святый как же я тащусь от ее постов',
#  'спасибо за контент ты чудо',
#  'пертурабо не хотел войны он хотел прогресса и искусства',
#  'прекрасный разбор',
#  'я просто хотел трахаться но император отключил эрекцию',
#  'император шеймит магнуса скрывает от него природу варпа натравливает волков магнус предает император',
#  'я просто посадил на коленку а вы тут все сразу педофил',
#  'получается что два полубога были балбесами с интеллектом ребенка магнус например не мог не понимать что находится в имматериуме особенно учитывая что именно его легион охотился за культами по всей галактике если же нет то он заслужил никею',
#  'это один из немногих артов где перт выглядит приятно',
#  'это война никогда не закончится потому что они вечные враги однако есть один шанс кто знает тот поймет',
#  'кругом пи 8381 USER один я дартаньян пертурабо осаждающий очередное укрепление',
#  'огромным удовольствием было описывать как случилось то что случилось и почему а также дразнить вас всеми этими непостижимыми тайнами когда на самом деле все это пришло из за непонимания будто император все знает и не совершает ошибок всем работягам кто в 2 2 ломает копья про императора и магнуса посвящается это незначительный кусок предисловия гая хейли из одного свежего романа линия на деконструкцию образа императора будет продолжена арда и под знаком сатурна плохи не сами по себе а в перспективе то император в величайшем труде видит сквозь тысячелетия а то близорукий словно и не имеет тысячелетнего опыта так что очередной бугурт не имеет смысла от слова совсем',
#  'это он в оке ужаса так развлекается',
#  'снова игра снова слова снова тысячи голосов тяжесть оков тяжесть веков тяжесть наших тысяч снов тысяча сынов',
#  'спасибо за пост',
#  'магнусу и лоргару не открыли сверхъестественную природу того с чем они решили иметь дело и не предупредили о проклятии которое несомненно последует первый мог бы и допетрить сам благо контачил с батей и сигиллитом а второму хоть кол в башку вбей а остальные примархи в массе своей либо поняли приняли либо внезапно им объясняли маннус как пример',
#  'если бы мы заметили если бы мы увидели каждый раз одно и тоже на протяжении всей истории знаков и знамений было предостаточно в том что мы их не заметили винить нужно только себя',
#  'хм сигвальд став демоном одет в более сносную броню чем фулгрим',
#  '',
#  'в детстве хороший был мечтал о светлом будущем но люди меняются как оказалось и не только люди',
#  'рь',
#  'многие пишут эммм ну вот пуньк среньк он аоевал там оййй пук он страдал сильно остальные то легионы так на расслабоне впк вели',
#  'эх жаль черные храмовники а не повелители ночи сыны конрада ведут войну намного интереснее',
#  'трог и крелл передают привет',
#  'когда все таки мстишь фурри за брата',
#  'сжечь треклятую гадину',
#  'а с чего вообще пошел хейт фурей во вселенной wh4 k',
#  '',
#  'несущие слово обиженные чуваки сыны преданный легион я посмотрю как тебе будет приятно общаться с отцом когда твой родной брат по его поручению разрушит все что тебе дорого и сломает еще спину тебе магнус конченный идиот конечно но сыны это лучший легион что был хотя как мне лично кажется он почти что вне всего даже хаоса',
#  'чем вигилус то кончился',
#  'хотелось бы постов и про имперских хаоситских рыцарей немножечко',
#  'ну импи мог бы не предлагать магнусу ультиматум уничтожь свой легион и мы устроим твое возвращение в империум это был просто 5iq мув',
#  'классика',
#  'на самом дне глубины нет нумерология астрология и прочая эзотерика не поганое колдовство а научный способ подчинить варп мортарион в его голове не по уши в имматериуме а всегда может слезть хоть завтра но вот уже 1 к лет оно вс еще не настанет более того и сам нургл в голове этого титана мысли лишь инструмент от которого в будущем можно будет отречься',
#  'к сожалению папку морти ненавидел сильнее чем псайкеров хотя это уже тавтология',
#  'крестьянин',
#  'просто плохо прописанный персонаж',
#  'все гораздо проще мортарион входит в список тех примархов чья судьба была решена еще до их рождения был же рассказ где говорилось что мортариона и гвардию смерти давно ждали в садах нургла то же самое с остальными павшими примархами единственный кто не стал их пешкой был альфарий омегон',
#  'никогда не было и вот опять',
#  'то чувство когда батю ферруса убили в начале а братья вспоминают его только с добрыми и ламповыми настольгическими чувствами всю ереси и вообще были бы рады будь именно он на их стороне',
#  '',
#  'если я все правильно понял то в погребенном клинке он так расстроился что его легион подцепил варп ковид и сыновья один за одним превращались в чумных зомбаков что пошел погулять по обшивке корабля подумать развеяться пока не увидел дедулю во всей красе и не смог больше сопротивляться судьбе ну и коррапченый уже тифус постоянно мозги пудрил пока они летели к терре так бы он его конеш за борт выкинул бы его еслиб не дружба детства в общем хорошее произведение',
#  'пертурабо нянчится с сироткой дорн отстраивает приюты для сирот вкп ик осваивают навыки ухода за детьми',
#  'так толсто что аж тонко было весело',
#  'мне кажется или это пародия на мойти пайтона',
#  'все три дебила',
#  'типичная осада железных войнов крепостей имперских кулаков',
#  'просто еще немного унижения железных плакс',
#  '',
#  'я даже не удивлен',
#  'были бы у эльфов миньки такие же красивые как арты',
#  'если кому интересно и если кто еще не читал классно осады жв описаны у грэма макнилла в омнибусе железные воины про полукровку хонсю',
#  'хочу еще',
#  'ааа есть перевод',
#  'юмор всем полком смеемся',
#  'ересь',
#  'госпожа комиссар бдит за дисциплиной',
#  'очень практичный шланг в голову входит это дерьмо вкачивать или выкачивать',
#  'какие крылья атасные у ребят',
#  'мм лоялам теперь тоже шланги в ухо положены для подачи варп даста',
#  'друг просит фулы братцы грозит инквизиции пожаловаться',
#  'это нурглячья пиявка атакуе',
#  'too hot',
#  'а что сейчас с ангелами за движ пошел',
#  'зная художника есть версия и с членом',
#  'блютуз гарнитура походу',
#  'раньше косил траву теперь воняю го ном и кошу траву',
#  'одобрено инквизицией',
#  'где одмин волколюб что он может сказать за свой саплай',
#  'выпускной в схоле',
#  '1 к лояльности',
#  'без шуток арт потрясный',
#  'мммм',
#  'звуки неистового распаления веры до критического заряда лазгана',
#  'стоп картинка мисс декабрь еще в ноябре это какая то уловка люди не верьте картинке они хотят испортить недрочабрь',
#  'кто еще разглядел мефистона справа на заднем плане',
#  '',
#  'бойся меня но повенуйся',
#  'фуллы будут только после первого числа',
#  'есть у кого нибудь последний арт в цвете и не обрезанный',
#  '',
#  'пс там это в девятку тихо вернули не варп даст а сила ваала походу',
#  'это что агитационный имперский плакат тип записывайся в гвардию',
#  'а где же лучший пикт с этой госпожой',
#  '',
#  '',
#  'книга шрамы и рассказ демонология частично показывают ход мыслей мортариона даже ныряние в гниль нургла у морти вышло исключительно из за его окружения в котором как оказалось он банально не шарил',
#  '',
#  'все ясно близы сп или и сделали из него перса для своего недо tf2 это шутка если что',
#  '',
#  'это какая то модификация кастеляна',
#  'чебурашка от механикус',
#  'что за автоматон',
#  'почтенные сенаторы для начала я не хотел бы восхвалять перед вами себя я хотел бы почтит отца в его честь я объявляю свой срок на посту консула началом новой эры эры нравственно и добродетели благородства распутству и хаосу которые нам довелось пережить будет положен конец рим вечен',
#  'что то аниматрица вспоминалась',
#  'и восстали машины против человечества',
#  'дык он и не против',
#  'только по четным дням недели по нечетным наоборот',
#  'но ведь рога сигвальда ужасны это безвкусица хаос получи рога еще б крылья летучей мыши приделали для оригинальности',
#  'типичный первый',
#  '',
#  'пройдут 4 тыс лет но нарушать женевскую конвенцию будет весело всегда',
#  'был шикарный пост перевод с the crusade когда при осаде столицы планеты робаут выверял приказы организовывал штурм и занимался снабжением войск контингент та увидев такой цирк подвинул робаута в сторонку чтобы он мог наблюдать как воюют настоящие гачи темные ангелы робаут благоразумно отошел в сторону доверешись профессионалам и не прогадал через пару часов контингент та прорвавшись к центру столицы дружно взлетел на воздух в огне ядерного взрыва вместе с верховным магистром разумеется так что это не мем а часть секретной доктрины легиона p s фрагменты брони боевых братьев та находили в течение нескольких месяцев по всему контененту',
#  'а когда это та давали нех для уничтожения чего нибудь',
#  'кстати слаанеш в эре сигмара реально стала папой мамой',
#  'а в ч м суть мема фулгрим и сильнее и выглядит лучше зигвальда',
#  'с места событий',
#  'ребят насчет миньки сигвальда ему можно будет поменять ноги на хвост',
#  'может он сейчас так и живет у себя на планете в оке',
#  'такс такс про фута версию уже спрашивали',
#  'огнь',
#  'true roman bread for true romans',
#  'кому фариту редлоссу тогда уж',
#  'fulgrimus femixius',
#  'это с кем кхарн сцепился',
#  'читеры из хсм которые притворяются крутыми собирателями черепов хотя без баффов чуть более скилловые космодесы на которых в свое время обратили внимание боги хаоса а вся их крутость это читерские баффы от варп сущностей из чисто эгоистических целей грубо говоря кхарн красавчик потому что он читер',
#  'друже может кто за конец времен фб пояснить я вроде общую инфу прочитал но так и не могу понять что там с предательством теклиса',
#  'космоволки покинули помещение',
#  'это многое обьясняет',
#  'фурри враг народа',
#  'смерть фурри',
#  'плохо шарю в инглиш поэтому кто нибудь не подскажет о чем разговор был',
#  'голосом габриэля ангелоса хороший все таки актер озвучки у него',
#  'люди фурри кста',
#  'а я так и не понял что храмовники с сынами фенриса не поделили в этой истории может объясните',
#  'эти хаоситы такие забавные',
#  'f ультрамарину',
#  '',
#  'а кхарн ростом с примариса',
#  'почему у него робо жопа вместо головы',
#  'субтитры уже есть',
#  'это современный арт',
#  'обсуждают как саню придушили',
#  'альфарий не палится на заднем фоне',
#  'так они же себя мнят сангвиниями тут целая рота гачи аниме ангелов должна сидеть',
#  '',
#  'но ведь они не видят своих братьев как хоруса',
#  'что то ангелов то не видно',
#  'куча хорусов и альфарий позади',
#  'знак расчленителей не обслуживать под барной стойкой',
#  'это крч как пьяный неуравновешенный контуженный человек с обострением',
#  '',
#  'ти хорус нет ти хорус',
#  '',
#  'простите конечно но этот мем говно',
#  'а белые шрамы не использовали псайкеров после запрета',
#  'что то вроде теплим бом бом терлим бом бом будешь использовать псайкеров и уничтожу легион',
#  '',
#  'а вот и концовочка удаленная',
#  'жду когда флешгитсы стравят волков с храмовниками по причине фурри',
#  'блэ как с утра начнут есосить влка фенрика то все все ука кому не лень писосят волков почему да этож просто ууууу волчатинааа уууу фурриеопство а толково обосцать ту же тысячу сынов низзя они пострадавшие прям блм какой то насцать на другие ордена легионы прям никак',
#  'волк поможет своему брату волку даже если для этого придется сломать законы отца волка ибо мы волки ауф',
#  'а лев тоже использует силу фенриса он же во всем первый даже как жопошник он первый',
#  'тогда получается тысяча сынов использует силу тизки',
#  'лицемеры что с них взять',
#  '',
#  'какого хрена мем про льва а вы волков суете',
#  'ахаххах и смех и слезы',
#  'ну не совсем так кроме того что фенрис работал по типу фильтра волки и шрамы применяли примитивную магию метания молний и фаерболов а тысячники сложную оккультную систему об которую быстрее зашкварились плюс их фамильяры были натуральными демонами без защитных контуров которые им ту самую вилку в спину и воткнули при сожжении просперо в книге про люция какой то тысячник ему прямо это сказал что их развели как лохов от чего мечник ржал как орк',
#  'жалко дизов нет в вк',
#  'ну так и волков и правда другое',
#  'ну как б энергия прошедшая через дух мира чистая моркая не пропускает говно из варпа уже только аутисты думают что маги сынов и рунные жрецы одинаково работают',
#  'а где дауны которые будут говорить что все еще не астартес я вас потерял',
#  'это ересь',
#  '',
#  '',
#  'левому проткнут в живот а правой примарх прикажет уничтожить астрономикон',
#  'нет',
#  'псина он в вахе псина',
#  '',
#  '',
#  '',
#  '',
#  'лансер и сайбер из судьбых сколько там версий',
#  'гавно',
#  '',
#  'ходит легенда что они жрут еретиков и ксеносов',
#  'лайк волки аутисты',
#  'ммммм я думал у баб есть отдельная броня',
#  'вахоебы консерваторы в комментах негодуют интересно наблюдать',
#  'после этого мой мир никогда не станет преждним',
#  'id25654 1 александр как говорил дорн руссу на терре я по прежнему считаю тебя лицемером',
#  'когда же эта бессмысленная война кончится',
#  'про псину из ордена псин уже шутили',
#  'brothe get the flamer',
#  '',
#  'fate 4',
#  'а почему конь парнокопытный',
#  'а там есть кровь девственницы 5 летней выдержки',
#  'хм а ничего так что дух фенриса это правда вон во время осады рунный жрец его призывал',
#  'не варп а сила фенриса и жрецы верят в это хотя и понимают используют границы не позволяя себе лезть дальше того с чем могут не справится и не жаждут этого в отличии от тс которые как и их дурной батя считали что знают все лучше всех и даже лучше всеотца',
#  '',
#  'рябяки не забываем о пропорции наказания соответственно поступку за метание молний и гадание на рунах например арест псайкера и его командира а магнус на минуточку открыл стабильный варп портал под жепой императора с помощью высших офицеров легиона поубивал кучу ученых поломал оборудование и похоронил надежду человечества на защиту от варпа блохастые конечно лицемеры но они такой херни не устраивали',
#  'шутка вроде про льва что не умеет читать',
#  'так русс же был главным инициатором эдикта а потом говорил что хаос можно победить только силой варпа',
#  'даже в меме тысячник долбо б который спорит с малышом и самое веселое малой его выносит лол',
#  'у них есть замечательная отмазка это сила фенриса это другое ничего не напоминает',
#  'странно такое читать с учетом того что лев не умел читать а волки в поле себе умели да сам русс был инициатором эликта насколько я помню и волки крайне не любят псайкнров и косо смотрят на библиариев хотя у самих есть рунные дрецы которые помимо своих дел в легион являются по факту библиариями но в бой их редко берут и мне интересно почему тут в группе так яро ненавидят волков если читать книги они часто приходили в моменты когда уже империума списал планету в потерю а полки и граждан умершими да в империуме к ним осторожно относятся после проспера но волчьи лорды не раз проявляли рвение и стойкость там где большенство других орденов бы отступил ось да они не следуют кодексу но волки не раз ставили жизнь граждан империи выше своей приходили туда куда другие ордена не приходят на помощь считая это бесполезной тратой ресурса да ордена есть еще такие же',
#  'у вселенной зв оказывается есть прото криговцы взгляните',
#  'ересь',
#  'опять бабомарины задолбали уже',
#  'офтартес ат мира лофадей',
#  '',
#  'ну а серые рыцари тоже черпают силу из варпа но при этом их стержень позволяет им творить из варпа магию которая противостоит демонам',
#  'конь в фартуке',
#  'магнус ты ли это',
#  'а лоргар где',
#  'мегатрооон',
#  'пертурабо теперь целиком и полностью куском железа живым стал после демоничества',
#  'кстати что таки получилось с гвоздями у ангрона просто в предатель кровь кровавому богу лоргар говорил что дескать гвозди бы его убили а превращение в демон принца от этой участи спасло но на всех артах он по прежнему с гвоздями',
#  'омегона тоже что то не видать',
#  'а хиккан',
#  '2 уву',
#  'фулгрим теперь баба штоле',
#  'лоргар прям поднялся хаос неделимый теперь с ним вряд ли кто справится',
#  '',
#  'а где лоргар',
#  'falabaloo и david haire один и тот же автор',
#  'у фулгрима сифилис7',
#  'во первых мы отлично читаем особенно руны а во вторых наших жрецов на никее не запрещали',
#  'фулгрим чем то на метатона из андертеил смахивает',
#  'какие красавчики',
#  'очень крутые работы',
#  'так более правдиво',
#  'ниал и исакар ор',
#  'лолгар',
#  'так и вижу объявление одинокая кобылка ищет своего противогазного наездника телефон 88 5553535 спросить комиссара рехтгоффена',
#  'намолил',
#  'насосал',
#  'глаза как у козлика',
#  'лион шоколадный палец из дока2',
#  'шикарный',
#  '',
#  'был похож на императора внешне внушал восхищение своей благостью и красотой был буквально золотым мальчиком и в какую мерзость превратился мдэ и это чисто внешне не говоря уже обо всем остальном',
#  'отвратительнее него может быть только эреб',
#  'а где лоргар',
#  'ваша ваха это аниме',
#  'фулгримм в какую то цыганку превратился',
#  'пертурабо не демон',
#  'только 4 примарха которые присягнули на верность одному аспекту варпа стали демон принцами остальные в меньшей мере подвержены изменению варпа',
#  '',
#  '',
#  'волки не тысячники',
#  'так че отвалил пиздюлин вороненку',
#  'глаза как бы намекают что он баран',
#  'лион с дотки',
#  'вот они слева направо',
#  'годные арты',
#  'ну а керз типа еще какие бы точнее его душа которая не затронута хаосом так как находится в эльдарском камне душ',
#  'лоргана не хватает',
#  'а металический то чей',
#  '2 мортарион',
#  'а третий кто',
#  '',
#  'это не считается псайкером если назвать его рунным жрецом',
#  'он окрасил себя в те цвета в которые он себя окрасил',
#  'сразу приходит на ум врата хель ака кибернетическое воскрешение более того пассажи про железных людей из the lord of the first отлично дополняют экстракт',
#  'в галактике существует огромное количество мистических артефактов широко распространенных среди бесчисленных миров и флотилий артефакт это априори не то чего много вот же пишут без ума галиматью',
#  'фулгримка ха ха словил',
#  'здесь плохо все',
#  'гв выпускает ролик про новый год комьюнити гримдарк умирает но этж просто поздравление',
#  'жду анонс легиона новогодние канибалы или шрамы святого санты',
#  '',
#  'да вы оборзели а че там про гс ляпнули',
#  'волки во многом были исключением из правил тем кто только считал себя исключительным до сих пор невыносимо больно это принять',
#  'марш антипрививочников',
#  'будь на другой стороне жилиман и его детишки можно пошутить про битву прививочников и антипрививочников',
#  'обалденный арт морт эпичен',
#  'а ведет наш легион сам примарх мортарион',
#  'gathering storm',
#  'великий непривитый очень эпичен он точно оправдывает свой статус мрачного жнеца',
#  'морти смотри морти',
#  'хватит на сегодня интернета',
#  'ржавые вонючки',
#  'это оф арт',
#  '',
#  'лион',
#  'классный арт поза морта доставляет а ты уже обчихал своего соседа',
#  'у меня даже на экран пара мух села',
#  'а если мне понравился веселый ролик и арты то как считают уважаемые специалисты из комментов мне уже пора лечится',
#  'копейщику люминет подарили морскую черепашку',
#  'вот вам агрессивные фанаты еще арт по фате',
#  '',
#  'не ну гнилушки отлично смотрятся',
#  'мы все альфарии',
#  'на первой пикче изображен легионер предателей который превращается в легионера предателей',
#  'когда все альфарии а ты омегон',
#  'опять чьи то влажные фантазии о том что все что делается в сороковнике это план альфа легиона',
#  'а че та под альфария косят хотят лояльный орден порочить',
#  'бедный альфалегион все кому не лень под него маскируются и творят всякую фигню',
#  'omegon s wrath',
#  'как работает эта маскировка она основана на пси силах или же технологиях',
#  'фигасе годнота',
#  'опять лоялисты маскируются под альфу',
#  '',
#  'все альфа легионеры поддались хаосу или кто то все же остался на стороне человечества ведь изначально у них были хорошие побуждения',
#  'фигасе говнота',
#  'вот что нумерология животворящая делает',
#  '',
#  'есегуэй',
#  'хэх',
#  'нормально режу идонетов на аксессуары спейс марам',
#  'а то что indomitus так хорошо продался что гв пришлось снова делать новые коробки про это мы промолчим',
#  'можно еще ножи на носки ботинок присоединить',
#  'нанотехнологии сынок',
#  'много дакки но желательно побольше',
#  'силовые кеды и силовой доспех с подворотами',
#  'ого коул нашел археотех времен тэт из совка ну тупа сжатие на максималках',
#  'млжете ориг миньки показать',
#  'гнилушка и китайчик хороши',
#  'новая коллекция от kanye west',
#  'мда',
#  'когда пошутили про митол гир',
#  'прием прием вызываю пояснительную бригаду',
#  'щеееееет',
#  'первый казахский космодесантник',
#  'красные кроссовки синий корпус gotta go fast',
#  'бляяяяяяя походу лоргар принял ислам',
#  'на втором арте он одевает наплечник на наплечник чтобы он носил наплечник пока носит наплечник',
#  'хоть одна бы конкретика в тексте прогон воды по трубам',
#  'до слез',
#  'вызываю армию примарис лейтенантов',
#  'zet kant bee ehaf dakka',
#  'а не слипнется',
#  'stonks',
#  '',
#  'не знаю как вам а мне ересевая бронька больше нравится чем из 4 к есть в ней своя изюминка',
#  'i need koumiss',
#  'теперь мы знаем откуда взялся копюшон библиариев 4 k',
#  'меня больше интересует почему новая модель чернокнижников с капюшоном',
#  'собсна так и выглядит любой релиз для примарисов еще не хватает надписи g i joe для полного комплекта',
#  'и как всегда слабоумные астартес судя по размерам голов',
#  'естественно длинноухие же помогали хуманам разбирать железных людей',
#  'за око ужаса и слаанеш ушастых под корень надо вырезать без разницы цвета или былых заслуг',
#  'почему ублюдки то лол',
#  'ошейники против психических сил кхорн одобряет',
#  'рога хит сезона',
#  'что за юнит',
#  'неплохо выглядит рога органично сочетаются вообще удивительная миниатюра для слаанешитов у которых что не минька то сами знаете что с тентаклями',
#  '',
#  'каво',
#  'о антагонистка первых сезонов могучих рейнджеров',
#  'а гв молодцы поняли что женские лица у них не получаются и закрыли его тряпочкой умно',
#  'о у нее подвох',
#  'транс колдун',
#  'вот она какая шамаханская царица',
#  'как люди в тэт вообще всех орков и эльдар не истребили',
#  'сначала ничего не понял а потом как взял и вообще ничего не понял',
#  'все как обычно сверху колдунья снизу колдун',
#  'жди себя в прошмандовках хиша',
#  'одобряю',
#  'как тебе такое тифон',
#  'свет мой зеркальце скажи',
#  'ебббааааааать неужели на хаулер можно будет поставить плевалки аносны через арты',
#  'олдскул прям',
#  'олдовыми артами завеяло',
#  'я дожил до этого гримдаркового кодекса дефгардов',
#  'все косплеят альфу бедная альфа как она только держится под напором столь подлых и беспринципных легионов тоже мне лоялисты',
#  'почему рот в примарисах',
#  '',
#  'omegonswrath',
#  'чтож для колдуна уже придется искать альтернативу а так все хорошо начиналось',
#  'а чего это ублюдки они же ксеносов крошили',
#  'что это за звук лейтенант похоже на звук перекатов и он приближается я не лейтенант я альфарий',
#  '',
#  'а разве весь альфа легион предатели я где то слышал что некоторые альфа легионеры сохранили верность императору',
#  'плазменная винтовка из фолыча ееее',
#  'болтер тысячи истин',
#  '',
#  'в чем прекол я прост с деревни',
#  'пояснительную бригаду срочно',
#  'это рояль в кустах настолько толсто что у фабия от улыбки рожа треснула и ручонки загребущие вспотели',
#  'завет огня никого не смутил да',
#  'это фотошоп или реально кто то подзUSER',
#  'а куда дорн ушел',
#  'на глазах явный любитель скинов',
#  'у дорна уже были упоротые фиолетовые мутанты упарывающиеся в религию и расхерачившие пол фаланги сарпедон передает привет из ада',
#  'ребят это еще жиля запретил коулу использовать гоносемя предателей',
#  '',
#  'читал при ереси про эту технологию классный вышел рассказ',
#  'сейчас читаю старая земля спойлер вулкан раздробил статую и шевелящуюся серебряную руку это что получается с помощью некротехники часть души горгона вернулась в эту руку вот наверно ферус офигел от чувств',
#  'lol',
#  'куда ни плюнь у любых лоялистов всякие вундервафли по карманам распиханы способные нагибать целые миры лучше бы ховербайки вернули',
#  'в чем прикол',
#  'орден называется сыны феникса ок но фениксом называли фулгрима panic их расцветка и геральдика напоминает детей императора panic понятно что это прикол и они наследники кулаков но все же на мысли наводит',
#  'интересно в основе этой технологии случайно не богатыри были из рассказа милосердие дракона',
#  'еще в томном империуме коул говорил жиле что мол легионы которые стали предателями были частью замысла императора поэтому их нужно восстановить и геносемя для этого имеется жиля на это сказал нетъ а коул такой ну нет так нет щито поделать по факту там должны быть не только дети императора и тысячники но еще и миражоры и несуны в общем полная колода',
#  'уриель вентрис теперь тоже примарис получил ли примаризацию демонический паровоз геймс воркшоп не уточнило',
#  'ну как обычно ждем потом тут спойлеров хорус умрет',
#  'а полководцы синистер будут',
#  'филлер',
#  'френч опять хотя это даже хорошо',
#  'пошаговая стратегия с описанием ходов в книжках',
#  'фраза ваще чума приобретает другой смысл',
#  'таки поднялся до примариса',
#  'ну это было ожидаемо',
#  'глядит внущительно',
#  'это ведь так сложно собраться хотя бы трем темным примархам и вместе кокнуть последнего верного сына императора нет что вы они все будут по очереди приходит получать пизд ли убегать затаив обиду и обещать что атамстяттт и так переодичностью в одно два столетия',
#  'а хонсю на огонек заглянет',
#  'если хоть немного юмора про кугата и демонов нургла будет значит можно читать',
#  'интересно его по итогу не абба ли лично прикончит',
#  'о аркадий паровозов',
#  'юра был юра есть юра будет есть',
#  'вангую будет битва на дамносе',
#  'интересно убьет ли мортарион жиллимана',
#  'капец убогая',
#  'четкий',
#  'это его реальная официальная миня или же',
#  'слишком много слоев краски на голове',
#  'голову с плеч и менять на что то менее бесячее хотя зачем мне вообще вентрис',
#  'плоскостопие 4 ой степени',
#  'на мой взгляд первый нормальный арт с жилей',
#  'падажжи третья а где вторая',
#  'арты жили прям сочные жду полноформатных',
#  'в парии ден такого намутмл и альфа и несущие слово и упоминание магнуса интересно что будет дальше',
#  'хвала богам эта книга выйдет',
#  'твоюжмать',
#  'оно же стоить будет как титан модели варлорд',
#  'уррррааааааааааа гришка и альфарий снова в деле',
#  'жилю заразят божественной чумой но вернется русс и вылечит его мъедом',
#  'эти книги происходят после того как ее титан хаоса в кому отправил',
#  'теперь главное дожить',
#  'что у него за угловатые силовые тапки и почему они так убого смотрятся',
#  'суровое чтиво в первой парии дядя дэн собрал все сорта хаоситских фекалий в одном месте в храме клона биквин собрались продать несущим слово в доме госпожи гло сидел босс качалки из детей императора который из кусков ткани себе силовую броню и мечи сделал а гигант в доспехе развалюхе и говорящей за него псиной оказался альфа легионером словом ооочень забавно читать',
#  'уродомарин',
#  'а омегон жопа гидры',
#  '',
#  'где паровоз карл',
#  'сколько можно всякой куйне просыпаться в варпе когда уже проснется кто то из лояльных примархов',
#  '',
#  'это лунный клан',
#  'страчан',
#  'перевод плиз',
#  'а с феликсом что или он теперь темная эльфийка',
#  'hidra dominatus',
#  'кто то теперь сестра битвы mazafaka',
#  'слишком много слоев краски и слишком мало паровозов',
#  'любопытно',
#  'она написана на кокни или бл решило не прикалываться как с механикусами',
#  'а написана она как будет адекватным человеческим языком или опять словно школьник оригинальный коммент пишет',
#  'у меня вопрос а книги про прохождение готрика в аосе перевели',
#  'да неужели 8 лет карл 8 лет ждал продолжение парии',
#  'как то мелковато после гигантов драконов и демонов старого мира да он и в новом успел разного понавырезать',
#  'это че за вид ксеносов',
#  'автобиография босса',
#  'примарх которое сообщество заслужило',
#  'и что кто могущественный проснулся',
#  '',
#  'иии разумеется придельно страшная лысая чернокожая сестра по центру между двумя белыми стоит она не может быть хоть немного милее красивее хоть немного женственней они могут быть хоть 3 чернокожими или все 3 разной расовой пренадлежности но столь явные акцент ни чем не лучше если бы одна белокожая сестра стояла впереди двух черных за чем гонятся не понимаю',
#  'эх если бы его так глупо не слили но близнецы круты',
#  'наконец то на нашей улице перевернулся лэндрейдер с варп конфетами',
#  'новая актуальная ксенология',
#  'привет детка меня зовут черубаэль',
#  'эх я надеялась что выйдет адб или что абнетт напишет две книги хотя френч тоже хорош конечно',
#  'хмммм кто же проснулся мб иннеад а может импи на молитвах и деяниях своих верующих таки стал богом а может горк или морк или сразу оба решили пастукать всех и сразу',
#  'в это же время в варпе пробуждается что то могущественное хонсю пертурабо пнул что ли',
#  'осторожно спойлеры там конечно намешано было клоны парий повсюду подавляющие ауру устройства есть штампуют в храме кулексус чтоли агенты альфа легиона разрывающий в рукопашке несущих слово инквизитор лорд детей императора с доспехом из лепестков и это уже набившую оскомину организация когните ох рушится восприятие мира конечно',
#  'то есть весь альфа легион',
#  'мы узнаем что император это альфарий а омегон это боги хаоса которые на самом деле горка и морка',
#  '',
#  'но я помидорка',
#  '',
#  'о брукс неплохо пишет надеюсь это тоже годнота',
#  'точней омеган',
#  'на самом деле альфарием был ламберт из ведьмака',
#  'король в желтом совсем жирный отсыл к лавкрафту',
#  'слишком сильное заявление',
#  'или твой батя что за сигаретами ушел шутка',
#  'все ясно админ омегон',
#  'нет никаких гарантий что админ не омегон',
#  'он своим же мечом стригся что ли',
#  'никто не знает где можно скачать сатурнин',
#  'шутка которую не выкупают',
#  'нечестивые технологии',
#  '',
#  'где его механический глаз',
#  'на самом деле там альфария небыло а главный герой это легионер которому гипнотерапией внушили что он альфарий и он скрывал правду',
#  'уриэль вентрис прошел рубикон примарис',
#  'так я это всегда знал',
#  'ты альфарий я альфарий вместе мы альфарии',
#  'почему сорроритка в белой накидке с белыми волосами должна быть ниггой',
#  'альфарий ван пис',
#  'он видел некоторое дерьмо',
#  '',
#  'похож на испорченного гея',
#  'то есть он не примарис',
#  'админ все эти книги которые ты постишь их можно скачать или покупать только',
#  'as the ossiarch bonereapers invade hysh люминеты',
#  'да не может быть вторая книга вышла',
#  'гитлер',
#  'гномы из аоса треножники из войны миров железные воины и машинариум хммммм',
#  'фирменный покрас от гв а так радует что вентрис наконец миньку получил',
#  'я думал что макнейл убъет его а на его место поставят нового примариса',
#  'если альфария убил дорн что стало с омегоном погиб от жили или жив до сих пор',
#  'ты альфарий',
#  'соник',
#  'типо в итоге он все таки живой',
#  'пасиб',
#  'нууу макнилл обещал обещал и вот хотя я уже потеряла надежду лучшего подарка наверное и не будет до следующего года',
#  'кто нибудь знает где есть перевод на русский первой книги',
#  'разве заклятый враг не легио атарус',
#  'книги не просто переиздадут их отретконят как минимум поправят таймлайн и возможно другие бэковые несостыковки',
#  'ооо еще и комент удаляет но не на того альфария напал',
#  'окажется что на самом деле все альфа легионеры страдают от травматического синдрома из за смерти примарха им кажется что они до сих пор ведут вкп и завоевывают миры для империума объединяют человечество освобождают людей от власти примитивной тиранической цивилизации спасают их из удавки религиозных суеверий и подготавливают к принятию имперской истины',
#  'о по дову книгу сделали',
#  'ну наконец то',
#  'лучшей товар на рынке имматериума волшебное зеркальце слаанеш туеву тысячу лет на рынке коррапта теперь можно приобрести и лавках фулгрима груша в подарок',
#  'как они узнали бросает дымовую бомбу',
#  'на паровозе приедет на калт',
#  'чуваки я думаю ересь начать читать можете подсказать с чего начать или без разницы',
#  'очевидный байт на пробуждающегося императора но ставлю что это иннеяд',
#  'опять меня спалили придется лучше работать над конспирацией',
#  'сразу видно что человек поведал много дерьма',
#  'оепта началось девочки не красивые а я хочу прекрасных но не слащавых астартес без комплекса вампира что бы могли в секс и были женаты вот хочу и все че гв не делает а а то продвигают тему замкнутого мужицкого братства что сплетаются в объятиях братских попахивает гей парадами че они с 8 годов повесточку продвигают для лгбти ах они жопашники легли под толераных еще в сама начала че то как это факт не мешает покупать миньки книги кодексы и прочие а тут бабы не красивые ай ай там вон ветриса сделали таким что понятно чего хоньсю сбежал хотя в первой книги чуть ли не в десна друг другу дышали от страсти тут примарх вон вообще с эльдаркой крутит веру не признает императора богом не считает не удивительно что рожу перекосило',
#  'только бы альфария не слили как пертурабо',
#  'только не френч',
#  'is his name paul',
#  'арт с нагиева рисовали',
#  '',
#  'нет все это время альфарием был я',
#  'на самом деле все литературные новинки представленные ниже это про альфария',
#  'учитывая что у всех примархов из серии глаза на обложке светятся это не альфарий',
#  'альфарий это гоша куценко',
#  'вот бы капитан тит вернулся',
#  'мы узнаем что настоящий альфарий все это время пытался спасти империум убивая все более новых альфариев вокруг альфариев вообщем я сам запутался в этом и есть вся суть',
#  'вентрису говорят че с хлебалом мать жива',
#  'пацаны в катафрактах люччие',
#  'гв раскроет главную тайну этот один и тот же макри или два разных',
#  'о уирелька выжил при трансформации',
#  'наконец то',
#  'пятый бог',
#  'помолодел',
#  'все еще недостаточно дакки',
#  'гидродоминатус',
#  'че будут спойлеры по этой книге',
#  'похоже иакс так и не станет мориаксем',
#  'а паровоз будет',
#  'в мире далекого будущего есть только нытье и смех темных богов',
#  'что с глазами моего бати и разве у меча императора есть ножны',
#  '',
#  'когда в 5 утра зимой идешь выгуливать собаку',
#  'сила фенриса',
#  'мухтар 4 к братья у нас труп возможно ересь по коем',
#  'так это новая ксенология или только о ксеносах из чернокжаменки и будут ли там иллюстрации',
#  'фиксирующей его разум на простой самовнушающей фразе ее повторение уполномоченным оператором запускает с',
#  'сестра анархия захваченная в плен тау собирается показать ксеносам что такое истинная вера звучит как начало порнофильма',
#  'жду перевод про постоянно изменяющуюся аксиому',
#  'сканирую обложку на предмет негров',
#  'горящие свечи на книжке мм как же это по ваховски',
#  'красиво звучит очень корпус мимира',
#  'ребят первую стену или сатурнайн перевели уже',
#  'интереса серво черепа из аэльдари в карауле смерти наследие этой технологии или были выдуманы независимо',
#  'что вы блин понимаете в эстетике',
#  '',
#  '',
#  'я не сразу догнал',
#  'отсылочки к мифологии',
#  'че он укурен',
#  'голова мимирона',
#  'а как называется первая книга серии',
#  'боец на переднем плане определенно намерен завалить титана с лазгана',
#  'а не разъясните для чайников',
#  'не за десант но отличная расцветка',
#  'как много в комментах глупых ньюфагов',
#  'броня с пехотинца starcraft ii',
#  'а читать то как удобно',
#  'прикол не понял но позади демон фулгрим вроде',
#  'а откуда вся эта инфа мимир некротеххника и тд',
#  'три девицы под окном пряли поздно вечерком император заходит в комнату нет ну нахер и выходит обратно',
#  'опять же сестрам битв совершенно не обязательно ловить мордой пули ну а те кто думают что после соприкосновения головы с чопой орка неагументированный хуман может отделаться брутальным шрамом вы подумайте еще раз гв прогибается под людей которые не покупают их продукцию сначала добавили на фигурки нейрозъемы которые непонятно к чему подключались потом запилили всем такие рожи что хаоситов пугать при этом рисовать няшных кровавых ангелов и ультру тут никаких проблем они ведь гмо качки кто их объективизирует',
#  'штрафники',
#  'напоминает бойца из промитея',
#  'я бы к космодесантнику с такой расцветкой спиной не поворачивался',
#  'хм даже с учетом перспективы он получается значительно выше остальных он разве не должен быть одного с бойцами роста',
#  'серебряной страже опять вернули ее цвета что ли или савье по старинке нарисовал потому что в книге по круседу в мирах саббат был показан этот вариант расцветки',
#  'finally some good art of alpharius',
#  'хм у болтера тактическая рукоять',
#  'мощный',
#  'бла бла бла такая то технология бла бла бла больше мы про это не услышим ни в ереси ни в 4 к',
#  'брови прямо модельные ох уж эти саньки',
#  'где наплечник из караула смерти не мог же он отказаться от такой чести',
#  'опять будет бой насмерть в котором все выживут и станут сильнее',
#  'надеюсь там будут только белые страницы на которых можно будет прочитать в ультрафиолете гидра доминатус балки',
#  'командор отправляем на калдерис ангелос конец связи',
#  'где паровоз',
#  'у всех рога зачем они теклису я не понимаю',
#  'гарри поттер и голова гидры',
#  'император меня услышал мои молитвы или их услышал дэн неважно жду перевод в общем',
#  'но дорн мертв поэтому его мнение никого не колышет может для кого то это новость но и без коула в империуме полно орденов геносемя которых берет свое начало от легионов отступников орлы смерти например',
#  'гоп стоп селестина',
#  'пятки подняла святость потеряла',
#  '',
#  '',
#  'горжусь этими киберхерувимами в любой непонятной ситуации держат плащ',
#  'кайны это не те ножи что метала псайкер из свиты рейвенора',
#  'зачем вообще пятки отрывать неудобнож',
#  '',
#  '',
#  'пятки оторвал сектор потерял',
#  'это просто одна из технологий что воткнуты в библиариев',
#  'сфоткай типа герой',
#  'не в тему опять эта европа опять этот склеп глубокого камня ребят го в горнило',
#  'выглядит как то по карлански что ли',
#  'давайте новый омнибус',
#  'где то загудел демонический паровоз',
#  'четко внатуре четко',
#  'разве альфач и омежка не носили броник похожий на космодесовский чтобы не выдать себя',
#  'мамкин модник',
#  'где картинка с пацаном и песком утекающим сквозь пальцыыыыыы',
#  'майк брукс мне последнее время оч заходит умеет могет книга уже вышла',
#  '',
#  'резко в росте сдал',
#  'пятки оторвал империум потерял',
#  '',
#  'ну что за дауны рисуют арты ну ладно наши написали постер к фильму аванпост где из коллиматорного прицела луч лазера лупил но здесь в 3 м мать его тысячелетии аутисты не умирают никогда штоле',
#  'лимитку хочу',
#  'лысый из альфы',
#  'аглая',
#  '',
#  'что за орден',
#  'переееееекааааат',
#  'народ а где магоса переведенного скачать можно',
#  'перевод если кому нужно ересь хоруса примархи альфарий голова гидры легенды изобилуют славными или печально известными деяниями сыновей императора тем не менее почти ничего не известно об альфарии самом загадочном из них поскольку лорд альфа легиона бесподобен в искусстве обфускации п п обфускация сбитие с толку запутывание его дары тайны и обмана настолько велики что даже его повторное открытие оставалось загадкой до сих пор но когда история исходит из уст змеи где заканчивается обман и начинается истина',
#  'не эти ли болты встроили в пси болтер серых',
#  'очень достойная поза',
#  'пропорции вышли из чата',
#  'дождались блин но надо с осторожностью денчик в магосе такого намутил гриха который несущего нарубил еще цветочки лепесточки',
#  'вроде как у гаунта глаза выжгли и теперь он с бионикой',
#  'гулиман вернулся о',
#  'тем временем',
#  'а я омегон',
#  'батя если вы купите эту скотину я выброшу ее отсюда на следующий же день прошло две недели',
#  'у всех примарисов болт винтовки и только у вентриса старый болтер',
#  'тож типа испивающих души с хемерическим гибридным прогениумом',
#  'и книга такая из рук делает перекаты',
#  'есть где fb2 посмотреть',
#  'забыл выключить огненный меч испоганил еще одни ножны',
#  'жалкая пародия',
#  'слава императору человечества',
#  'эт весь арт целиком',
#  'голову не сразу заметишь',
#  'зачем зачем им столько шлангов в животе гной откачивать',
#  'самые мерзостные еретики интересно если рядом с таким глушилка варпа заработает он растечется или останется в форме',
#  'случайное фото но сколько смысла',
#  '',
#  'самовар',
#  '',
#  'а у какого ордена такая расцветка или это фанарт',
#  'самое лучшее аниме лучший опенинг классная музыка ржака полная',
#  'как обычно без шлемов куда сморить тб шник',
#  'типичные индусы',
#  'смоуг',
#  'мне кажется это типичная феменистка',
#  'откуда арт',
#  'когда жахнул в лифте',
#  'а почему переиздают',
#  'верминтида сорок тысяч',
#  'полковник спросил меня какая моя работа я сказал ну делать что говорят он сказал что я чертов гений и дал мне еще одну медаль люблю гвардию с норк деддог',
#  'еее рескин верминтайда урааа',
#  'отдача у лазганов отдача у лазганов',
#  'почему так сложно огрину впихнуть физику ну он же ж здоровая туша он не может так резко дергаться',
#  'на удивление выглядит не дурно выйдет игра посмотрим пока что претензий нет',
#  'была такая же игра spacehulk deathwing 4 человека переходят от точки а в точку б убивая нпс игра провалилась потому что была скучной несмотря на графоний',
#  'ну если динамика будет на уровне верминтайдас то збс если на уровне спейсхалка то хз а так красиво крутой ролик',
#  'хотелось бы что бы добавили других персонажей пусть даже через dlc а так ждем конечно',
#  'я хочу эту игру',
#  'с детства так ничего не ждал пойду сыну покажу',
#  'годнота же там смотри и марины вступят в бой',
#  'такое уже было только в warhammer fantasy battles но все равно рад игре',
#  'мда уж акулы на то они и акулы',
#  'блин а я так скиттергейт на легенде не прошла надо успеть до выхода',
#  'бодрячком так немного пустовато без полноценных инквизиторов и маринов но в целом живенько',
#  'огрин это хорошо огрин это надежно даже если он не выстрелит он всегда может жвахнуть кого то по голове борисиус блейдус вальхалец',
#  'я не для того лез в подулий что бы сдохнуть',
#  'главное нет этого обоссаного пафосного маринада который в каждой игре превозмогает',
#  'требования какие',
#  '',
#  'лефтфодэд в мире империума',
#  'опять адепты маняфантазирования пытаются в аналогию по отношению к вещам которых не существует в реальном мире',
#  'вроде заебумба',
#  'шикарно я бы поиграл',
#  'опять кучу баб воткнули что за дерьмо видно и эта игра не взлетит совсем',
#  'где бл ремейк файр варриора когда ллюдям наскучит пилить игры про все побеждающих лоялистов',
#  'типа есть ересь хоруса есть времена вкп есть куча различных миров и кровавых сражений во вселенной вархаммер даже если вспомнить ту же коммору когда туда саламандры высадились эпик же ну неееееет мы сделаем самую убогую игру по вахе как обычно ни тебе истории падения целых легионов ни тебе эльдаров двигающихся с дикой скоростью ни гражданской войны ни войн с ордами хаоса неудивительно что эта игра малоизвестная и я не знаю точно но я бы не удивился если бы эта игра провалилась нахрен в прокате халтура виднеется во всем они не смогли сделать звук лазгана его физику чтобы было играбельно и как то бы отличались лазганы от огнестрела нееееет мы возьмем обычный звук огнестрела и обычную физику огнестрела и нацепим на лазган типа в фаллоуте 3 лазерные пушки имели свою физику минимальная отдача и свой звук выстрела это халтура господа эта игра настоящая халтура мне как фанату вахи очень обидно что не могут сделать что то годное уже столько лет по этой вселенной я все жду вкп и ересь хоруса а мне суют всякое дерьмо и говорят жри тваринка',
#  'а абаддон когда нибудь станет демонюгой уже 13 чкп провел а все эти чудики по одному и стали демонами',
#  'vermintide в 4 к',
#  'продано',
#  'а ничего так смотрится',
#  'лазган плохо сделан какая то отдача у фактически фонарика я всегда представлял лазган как пушку чем то похожу на ту из вульфинштейна то есть стреляющую не очередями а одним долгим лучом который выжигает и плавит цель',
#  'смесь верминтайда и спейсхалка',
#  'нуу чет как то не драйвово совсем наверно из за максимально генеричного музла на фоне а возможно реально действия мало показали',
#  'я мало понимаю в вашей ц й як його вахе але огр н був красив шим н ж ж нка',
#  'да все там нормалды будет лазган пофиксят нож которым огрин нарезает себе хлеб уберут потом еще докинут брони пушек персов и прочего контента',
#  'не открывается',
#  'вместо курильщика будет слаанешит с длинным половым органом им будет хватать и утаскивать вместо толстяка последователь нургла',
#  'отдача у лазгана серьезно',
#  'не нойте хотите и этат проект закрыли будут работат над ошыпками хотябы похвалите разрабов',
#  'очередной проект который пройдет мимо меня по причине отсутствия друзей',
#  'брат во имя императора не спускайся в комменты если только ты не поклонник нургла тогда все норм',
#  'а он будет в гейм кассе',
#  'мне deathwing понравилась хотя местами и было нудновато в целом неплохо',
#  'ябсыграл',
#  'ого новая верминтида',
#  'новая часть left 4 dead прекрасна',
#  'l4d в новой обортке',
#  'кастомизация будет надеюсь чтобы облик на другой полк поменять',
#  'присела на дары сланееш',
#  'чот я забыл это что ща легион',
#  'хоть кто то красиво лоргара из гвардии ворона нормально нарисовал',
#  'а русс с дальнобойным оружием ходил',
#  'галя жрааааать',
#  'какой то он египетский чтоли',
#  'пожиратель миров',
#  'это типа ангрон а если так то что с наплечниками',
#  'какой то он не то',
#  'потрясающий арт вот бы всех автор нарисовал до такой степени правильный арт по всем направлениям',
#  'кхарн косплеит ангрона',
#  'как же красив дорн',
#  'красавчик',
#  'кратос убил ангрона и забрал его броню',
#  'какой то он адекватный',
#  'раб и гладиатор до демоничества',
#  'похоже на ангвуна без дредов его',
#  'могли бы ему сабель и пистоль выдать',
#  'топор у него судя по ширине вместо щита',
#  'это же командор данте',
#  'midget',
#  'оружие не цепное че курит автор',
#  'стоп у него разве не два пилотопора да и наплечники не те',
#  'какой то не такой ангрон',
#  'еще никто не написал ну так я первым буду это же фростморнъ',
#  'итак из врагов я увидел культисты нургла уже счетоводы и гвардейцы главарь топящий судя по черепам на поясе за кхорна звери нургла великий нечистый если я не прав я не прав и поправьте меня в комментах если это я кого то перепутал или не узнал за темных божеств блет',
#  'если бы император все сделал правильно',
#  'посоветуйте игр по вахе толковых',
#  'если бы еще за астартес можно было бы погонять',
#  'мне его меч напоминает врост морн',
#  'как то слишком лампово вышло начиная со скорости геймплея заканчивая анимациями',
#  'каллимматорный прицел на лазгане это вообще законно',
#  'символично что за мирожором следует куча дерьма',
#  'где дитя и отец резни то',
#  'ыыыы блятъ',
#  'пьяная драка закончилась избеением культистов',
#  'там у чела слева на заднем плане с головой все в порядке башка с орешек',
#  'внутри тебя два волка один жопошник второй жопошник и ты жопошник',
#  'волки в цирке выступают',
#  'за этим бравым космарем точно не берсехорно которые нашли себе нового вожака',
#  'а можно для рабочего стола такое или на подобии',
#  'игра еще не вышла но великие вахоебы ее уже обосрали молодцы товарищи продолжайте в том же духе',
#  'когда же они поймут что ближний бой они используют в самых крайних случаях а не постоянной основе кошмар',
#  'сделал себе дома на стене',
#  'что за легион волки',
#  'два волка в форме уробороса хм магнус можно тебя на минутку тут пара вопросов к тебе байлу и коулу',
#  'вы нас радуете артами с космическими волками',
#  'какой собакен породистый наверное из имперский псарен',
#  'ммммм какая интригующая соритка',
#  '',
#  'обувь где потеряла а с крыльями что случилось',
#  'а чего они такие бледные',
#  'альфарий я и ты альфарий и сто альфариев вокруг',
#  'три альфария переглядываются',
#  'это оф арт',
#  'после этого арта тарантино стал фанатом вахи',
#  'бред какой то',
#  'аббадошка и малекитка',
#  'корраптиврейн',
#  'аббабаба',
#  'ну и мерзость',
#  'оу кто то применил магию 63 на малекита ну до ладно слаанеш одобряет',
#  'шутка о том что у крида кадия не стоит еще актуальна',
#  'ты альфарий я альфарий оба мы альфарий',
#  'сестра безмолвия как',
#  'или это абадон такой',
#  'интересно все ли чемпионы нурглиты космодесантники они в предпочтении я так понимаю из за регена устойчивости и т д а бывают ли чемпионы люди чемпионы из ксенорас из обычных людей ставших чемпионами нургла читал только про одного из генералов махариуса который обратился на сторону хаоса',
#  'ангрон нурглит',
#  'на бордерлэндс похоже',
#  '',
#  'все так уверены что это альфарии а вдруг один из них омегон или оба истина где то там',
#  'id6 735651 зак это совсем не молодежь я не о них говорю эти больше похожи на какой нибудь элитный авангард если дело дошло до авангарда старичков то возможно что молодежь и тактикалов уже порубили в фарш либо просто ситуация не из простых',
#  'как же хочется малекиточку',
#  'че полки кончились',
#  'ухуук',
#  'тут одна несостыков очка скорпионы мужики',
#  'опа ересь',
#  '',
#  'много одежды',
#  'ересь',
#  'а что с таким удовольствием давит абаддон есса',
#  'ох такой календарь мне больше нравится',
#  'братья со стигии viii и все ксенариты механикус требуют полные знания этого пикт снимка',
#  'где тапки проебала',
#  'привыкайте теперь весь календарь на новый год будет ксенофильским таутяне хруды орки da girlz гибридки генокрадов секс куклы некронтир короче засылайте караул смерти к художнику весь орден целиком отдельной ротой тут не справиться',
#  '',
#  'эльдарки это нормально особенно в наше время подпись робаут жилиман',
#  'чисто хорус и лемон рас опять сцепились по пьяни и испортили всем праздник каждую пятницу одно и тоже',
#  'после пробуждения примарха аэлда и человечество обретают новые точки соприкосновения культур и быта',
#  'неожиданно',
#  'человеческие полки закончились пошли по ксенорасам',
#  'нафаня сундук украли',
#  'gidra dominatus',
#  '',
#  'о третья часть left4dead наканецта',
#  'какой же всратый арт будто обложка женского романа',
#  'очередная унылая копия lfd с толпами одинаковых врагов в 4х стенах',
#  'а можно весь календарь скинуть',
#  'хочу брату распечатать',
#  'похожи на лекса лютора',
#  'широкий волк',
#  'народ как называется книга в которой леман ткнул хорусу заточкой в бок',
#  'на первом арте в глаза сразу бросается отсутствие щитов у пса либо они перегружены либо в титане сидят отбитые которые поверили в себя',
#  'третий постер прям так и хочется назвать лоуренс марсианский как одноименный х ф лоуренс аравийский',
#  'я не совсем понял как на первом арте альфачи погруженными в дорогу ходят',
#  '',
#  'по моему херня какая то',
#  'альфарий класса гончая войны не дурно',
#  'первый арт красивый но бредовый до жути',
#  'о первом арте пусть и с натяжкой но можно сказать что титанчик набегает на вайтран',
#  'арквейд на елочку нарядилась',
#  'няфистон',
#  'мефистон но только аниме',
#  'мефистоняша',
#  'она не кровь должна стирать',
#  '',
#  'мефистон одобряет',
#  'данте впал в депрессию от увиденного',
#  '',
#  'ну и раз пошла такая вакханалия',
#  'зачем вы скинули обычный арт с мефистоном',
#  'а почему у нее соски такие маленькие они тоже должны быть сверхчеловеческими',
#  'когда переборол черную ярость но анимел',
#  'кто автор рисунков',
#  'осуждаю',
#  'арквейд мефистон арквейстон',
#  'мефистон допримаризировался',
#  'видел кучу артов с мерсади олитон и эуфатией киилер но ни одного арта с игнацием каркази что за несправедливость',
#  'вспомни самый яркий секс потому что сегодня будет лучше',
#  'мы никогда не увидим достойны фильм',
#  'рядом не валялост хоть и круто',
#  'формы черепа нормальных людей моя',
#  'о надо утащить',
#  'очень вдохновляющие черты как будто герои мифов что и есть',
#  'какой то бездушный стилизованный дизайн у этой вашей лунной принцессы будто абстрактная анимеблондинка или герой ммморпг чей дизайн игрок не настраивал и не пытался',
#  'стелс задание гидры с цепными мечами рука лицо',
#  '',
#  'группа красных крыльев описанная в книге содержит лишь одного перворожденного карлана капитана ареса тогда почему этот капитан не стал магистром',
#  'случаи кровавой жажды были еще в индомитусе более того робаут про них в курсе еще со врем н мстящего сына а вот ч рная ярость конкретно с примарисами случится уже во тьме в крови когда мефистон утратит контроль на ангелом ч рной ярости в битве с кирисс были ли случае чя до скорее всего да но стоит сказать что от массового внедрения примарисов прошли считанные месяцы про стремительный рост числа псайкеров было еще в психическом пробуждении и отлично что книги начинают резонировать друг с другом хотя я бы отметил линию что примарисы офицеры что служили с примархом бросят вызов данте причем опять же никакой драмы в этом не будет во тьме в крови когда данте начн т свой аналог индомитуса а именно расширение the angel s halo всех недовольных заткн т он довольно быстро неплохой обзор',
#  'завязка вроде неплохая но если пишет опять хейли будет такой же картон как и в darkness in the blood',
#  'некоторые даже считают что данте слишком стар найс пополнение',
#  'ядриель убивает ареса был карлан и нет карлана',
#  'что за пять добродетелей',
#  'книга кончается вирусной бомбардировкой планеты после того как с нее эвакуировали всех важных людей практически все население погибло но сказали что планету реколонизируют а угри а вино что теперь будут есть и пить дворяне из ближайших систем',
#  'когда святая инквизиция уничтожает потенциально зараженных варпом жителей планеты поток говна в ее сторону не остановить когда кровавые ангелы делают тоже самое ну что поделать такова цена безопасности империума эх труден и неблагодарен путь святых ордосов',
#  'они были поработители они заполонили всю планету',
#  'так от поработителей только экстерминатус спасает еще с вкп более того кто то писал что и древние погибли именно из за поработителей а не ктан',
#  ...]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shalaev\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words("russian")
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
import pandas as pd
import numpy as np

# Считываем данные
n = ['id', 'date', 'name', 'text', 'typr', 'rep', 'rtw', 'faw', 'stcount', 'foll', 'frien', 'listcount']
data_positive = pd.read_csv('training_data/positive.csv', sep=';', error_bad_lines=False, names=n, usecols=['text'])
data_negative = pd.read_csv('training_data/negative.csv', sep=';', error_bad_lines=False, names=n, usecols=['text'])

# Формируем сбалансированный датасет
sample_size = min(data_positive.shape[0], data_negative.shape[0])
raw_data = np.concatenate((data_positive['text'].values[:sample_size],
                           data_negative['text'].values[:sample_size]), axis=0)
labels = [1] * sample_size + [0] * sample_size

# %%
data_positive
# Out:
#                                                      text
# 0       @first_timee хоть я и школота, но поверь, у на...
# 1       Да, все-таки он немного похож на него. Но мой ...
# 2       RT @KatiaCheh: Ну ты идиотка) я испугалась за ...
# 3       RT @digger2912: "Кто то в углу сидит и погибае...
# 4       @irina_dyshkant Вот что значит страшилка :D\nН...
# ...                                                   ...
# 114906  Спала в родительском доме, на своей кровати......
# 114907  RT @jebesilofyt: Эх... Мы немного решили сокра...
# 114908  Что происходит со мной, когда в эфире #proacti...
# 114909  "Любимая,я подарю тебе эту звезду..." Имя како...
# 114910  @Ma_che_rie посмотри #непытайтесьпокинутьомск ...
#
# [114911 rows x 1 columns]

# %%
data_negative
# Out:
#                                                      text
# 0       на работе был полный пиддес :| и так каждое за...
# 1       Коллеги сидят рубятся в Urban terror, а я из-з...
# 2       @elina_4post как говорят обещаного три года жд...
# 3       Желаю хорошего полёта и удачной посадки,я буду...
# 4       Обновил за каким-то лешим surf, теперь не рабо...
# ...                                                   ...
# 111918  Но не каждый хочет что то исправлять:( http://...
# 111919  скучаю так :-( только @taaannyaaa вправляет мо...
# 111920          Вот и в школу, в говно это идти уже надо(
# 111921  RT @_Them__: @LisaBeroud Тауриэль, не грусти :...
# 111922  Такси везет меня на работу. Раздумываю приплат...
#
# [111923 rows x 1 columns]

# %%
data = [preprocess_text(t) for t in raw_data]

# %%
data
# Out:
# ['USER хоть я и школота но поверь у нас то же самое d общество профилирующий предмет типа',
#  'да все таки он немного похож на него но мой мальчик все равно лучше d',
#  'rt USER ну ты идиотка я испугалась за тебя',
#  'rt USER кто то в углу сидит и погибает от голода а мы еще 2 порции взяли хотя уже и так жрать не хотим dd URL',
#  'USER вот что значит страшилка d но блин посмотрев все части у тебя создастся ощущение что авторы курили что то d',
#  'ну любишь или нет я не знаю кто ты бля d URL',
#  'rt USER ох 9 d ну это конечно же USER чтобы у нее было много друзей ведь она такая мимими lt 3',
#  'rt USER у тебя есть ухажер нет мои уши не кто не жрет d',
#  'поприветствуем моего нового читателя USER',
#  'теперь у меня есть частичка сиднея sydney sydneyoperahouse URL',
#  'люблю маму и папу а в остальное я так влюбляюсь привязываюсь',
#  'rt USER как то я забыла что вчера приехал из деревни наш котэня и испугалась когда он утром пришел ко мне общаться доброе у',
#  'USER USER USER так было задумано да',
#  'USER дааааа ты ты ты и только ты',
#  'USER о нет вы ведь все равно обзоры урезаете просто одна версия сильно порезанная а другая полная только без мусора',
#  'USER смотри там случайно в аспирантуру не попади наука никого до добра не доводила',
#  'rt USER USER эхх а в угату о контрольных предупреждают уже на контрольной',
#  'USER а а то подумала что у тебя там пробежечка',
#  'USER USER зря вы с этой хуйней шутите я много историй наблюдал в режиме рил времени по работе с русскими которые разбивались на них',
#  'USER очень главное спасибо for медвед он работал клоуном аниматором',
#  'у нас есть прекрасная история как сдохнуть за неделю',
#  'USER сегодня столько поводов выпить что я уже не могу усидеть на месте',
#  'USER унылый наверное вдруг его перед этим чпокнули',
#  'rt USER USER USER 1 при поддержке администрации мо белевский район сборная белевского района по URL',
#  'поприветствуем моего нового читателя USER',
#  'как же хооорошо валяться но мой бедный обколотый попец хочет на прогулку URL',
#  'хоть у кого то заебись все настюх рада за тебя пиздец прям искренне рада есть все же справедливость на свете',
#  'да почему мне похуй то новерное потому что еще не ночь темная',
#  'блин хочется писать и писать всякую хуйню пишу но все равно хочется',
#  'USER USER а мне хотя бы расскажите что по чем',
#  'rt USER USER для тебя URL',
#  'USER я по первому не смотрю поэтому качаю в инете найди группу в вк оттепель там думаю все серии есть',
#  'предвкушение потрясающего уикенда праздник света гулять ночи напролет и любоваться огнями',
#  'я рааааааад ведь сегодня впереди вся ночь сериалы фильмы книга и кофе идеальная ночка',
#  'списком надо всем гамузом d URL',
#  'rt USER rt электрогенератор URL изсостоек и не победим',
#  'USER у меня нет фоток позже тогда кину',
#  'второй день подряд мне снятся сны с ромой я сошла с ума romaacorn',
#  'rt USER слушай коть можно я этим боком встану так лучше получается а у меня наоборот этот USER лучший человек',
#  'rt USER почти в каждых пиратах рт неимоверно радует своими политическими позициями в отсутствии понимания и фактов',
#  'оля ты очень добрая на самом деле а ты сучка злая бу на тебя да я та еще тварь заметь ты сама это сказала диалогивофисе люблю их',
#  'не иду завтра в школу первый раз мама так настойчиво не отпускала меня спасиибки',
#  'как же мне нравятся мужчины в строгих костюмах млею',
#  'USER так это пушистая скотина тоже дрыхнет круглые сутки просыпается только чтоб поорать возле миски',
#  'USER ахаха да нормээ с моим врачем мне ничего не страшно',
#  'встречайте мои супер одногруппницы будущие историки искусства и моды большиеоригиналы попятницамносимчерное URL',
#  'все я вас покидаю результаты гляну вечером биатлон',
#  'rt USER USER дыы но кто сказал что я все поняла ааххах URL',
#  'почти приехали в родное селенье москва рига URL',
#  'на уй ваши канары и мальдивы тут новая тема проскочила URL',
#  'rt USER а стояк теперь снова стояк вселенная вернула все на свои места',
#  'прифетигг солныско каг тфаи дила мну сичас фф больниську идеть к логопеду',
#  'USER да нашла фоточку в иг и нагло спиздила ничего с фотографиями меня уже статусы в вконтакте бывают',
#  'а у нас в нижнем слякотная погода брр но у нас офигенный привоз заходим заходим URL',
#  'короче видимо ни в какой архитектурный я не иду там капец конечно',
#  'USER ну в 18 сделаешь тогда я дарья а ты',
#  'USER плак плак надеюсь на драфте тогда их вытяну',
#  'USER а моя кроме поорать еще просится на балкон хвост поморозить минуту посидит и назад просится',
#  'каждому так болеть когда к тебе друзья в гости ходят',
#  'мам мне так хреново выпей таблетку и на работу на следующей недели пойдем в сауну мама умеет поддержать и добавить стимула',
#  '3 тысячи это не так дорого для пальто лол d т е пальто криса стоит меньше 2 тыс рублей',
#  'rt USER это так мило когда парни ставят на аву свои детские фотографии URL',
#  'USER опа дома никого помнишь что ты мне должен d',
#  'USER наверное ну все равно приятно d d d ахах я под столой вчера лежала',
#  'USER и работал а не как этот то потухнет то погаснет',
#  'USER лучше бы и то и другое кстати после сегодняшнего я кроху ненавижу еще больше',
#  'USER ох прям за год соскучилась чего забросила прекрасных мужчин не понимаю',
#  'rt USER вышел прокатится через 15 минут зашел назад весь мокрый дождь полил',
#  'USER а что за татуировка у тебя фото в студию',
#  'USER ого надо будет так попробовать с следующий раз d',
#  'USER ахахаха я тоже сегодня полдня играла в обломова d примерно до полчетвертого',
#  'rt USER ого на кинопоиске сделали саундтреки d а я и не знала очень удобнено',
#  'весь мой тви теперь будет наполнен долгожданным снегом из года в год он меня бросает URL',
#  'а еще я просрала кравченко все метры и теперь она хуй в инстаграмм зайдет',
#  'лежу в кровати закуталась еще бы вкусняшек кто нибудь принес',
#  'USER давай воронеж тебя ждет с распростертыми объятиями',
#  'сижу смотрю с братиком гадкий я всем добра',
#  'едем по мосту со скоростью 2 км ч под донт вори доставило',
#  'USER ахахахха прости но я немного занят dd в следующий раз обязательно покажешь всеееех ddddd',
#  'перемен ждала и дождалась теперь буду ждать лето',
#  'день выдался удачным я ожидала худшего но у меня даже настроение отличное и это несмотря на то что я ночью меньше 5 часов проспала',
#  'USER дааа так что приезжай загорать и сразу на чай этажом выше',
#  'q очень нравятся ваши песни андрей успехов вам a URL',
#  'айгуль маратовна сколько за ппт 9 из 2 из 1 спасибо за щедрость ну тебе же надо заканчивать уже вот это человечность',
#  'радостных выходных URL с помощью USER',
#  'классная позвала в клуб мммммммм очень интересно ахахаххаха',
#  'ой angel beats начинается 11 апреля весна становится все интереснее',
#  'USER опять что ли подозреваешь ну как для чего что бы знать насколько в разных городах живем',
#  'USER USER что уже все обломались с твитером скучно тут стало или что',
#  'USER оно ты не смотрела ты любишь клоунов',
#  'ostap cae group наш девиз и тут остапа понесло никогда не заканчиваем спикинг вовремя',
#  'дежурить с хомой и саней ахуенно ибо нихуя не делаешь весело люблю их',
#  'говорят что сейчас на такие портфели мода в городе правда URL',
#  '8 ые пришли я опять запредельно радуюсь часы черного цвета это двойная радость мояпрелесть URL',
#  'USER это он любит прикольно было бы наверное по мкаду на лыжах 8 км ч шпарить',
#  'USER ахах тут еще у одной девочки фамилия тимофеева была d 3',
#  'пальцы совсем отвыкли от гитары а та даже практически не расстроена',
#  'в 5 классе будет учиться на радость англичанке нашей',
#  'ты все время работаешь нееет а в какие дни ты свободна во все кроме пн вт ср чт пт сб вс эмм',
#  'USER USER ясно у меня сердце заходилось когда объявляли номинантов как будто я сама лично участвую',
#  'USER получается осторожно котлетку перекладываю в др посуду',
#  'USER USER единственное что меня расстраивает на бали невозможность сходить в кинотеатр с друзьями на интересный фильм',
#  'базарнов сегодня спрашивал чем лучше сушиться d парень весит всего 6 кг где то ахаха но он сказал что ему уже пора лол',
#  'USER маловато получается лучше незлобин тогда',
#  'USER я люблю тебя со всеми твоими истериками солнышко d',
#  'урааа USER вот я же говорила davaidinamo',
#  'все свое ношу с собой хорошая штука все же dropbox кто еще не в теме регистрируемся и получаем бонус URL',
#  'лента до сих пор не может угомониться с этим ай эм голос похож на билла соглашусь но бл как так они написали сразу раста песню d',
#  'дизайнер с большой буквы USER за 7 дней белые носки становятся черными проходя 5 оттенков серого',
#  'USER USER кама совести у тебя нет как ты не почувствовала такое',
#  'цена на билет на квн на сегодняшний финал от 1 на балконе камызяки URL',
#  'USER да вот и получается что хоть и москвичи а все как по понятиям привыкли так только и могут позорище еще и начальство вызывают',
#  'такой снежок идет мммм на улице просто волшебно',
#  'мой комп не выдерживает такого напора фоток от USER соколовскийяхочутебя',
#  'такая вот моя будущая работа дигистировать балык товароведы URL',
#  'интересно а почему ставит readonly в своих топиках когда там начинают общаться люди',
#  'USER да не я лучше тихо буду пялиться на них d',
#  'rt USER такое ощущение что я очень стар ох как это было давно USER URL',
#  'юля знает куда мы соберемся поехать когда ей стукнет 18',
#  'USER жаль что только в 218 году снова опоздаем',
#  'я попиздил патихардит ухахах хз во сколько вернусь надеюсь в час всем удачного времяпровождения 3',
#  'теперь я знаю страшную тайну зачем у монитора ножка имеет круглую основу URL',
#  'rt USER USER ааа точно спасибо',
#  'USER да да так все и будет кто где вечером',
#  'USER они там уже год но недавно в версии для пк они по другому показываться стали',
#  'USER влюбляешься автоматически классные слова',
#  'USER очень но все говорят что не очень можно на нг придти',
#  'USER значит тебя не интересует то что люди читающие тебя тоже смотрят этот сериал и им не очень то приятно читать спойлеры',
#  'USER почему мы с медалью походу тьфу тьфу',
#  'alexfilmfreak как и обещал действительно какие времена были URL',
#  'вот как google любит зиму сам эффекты добавил gif URL',
#  'USER придет тебе перевод на 5 рублей и нужно будет заплатить комиссию 43 9 для его получения o',
#  'всем добра и сгущенки спасибо URL',
#  'ура первая победа на выезде в этом сезоне наконец то жаль что не в основное время но хоть так',
#  'rt USER взял вот такой комплект у нее приемник чудный да теперь у меня все беспроводное и на батарейках',
#  'прекрасное утро проснулась полчаса назад а за окном снежоок',
#  'USER подстраиваетесь под чью то или есть своя',
#  'USER валяй d панд гони d у меня тожи панды есть давай ссылку на вк покидаю d',
#  'во всем саду воспитатели говорят что такое происходит только у меня в группе URL',
#  'проходят мимо две девушки а я как крикну как третью зовут',
#  'USER сегодня держу кулачки за хайда желаю вам взорвать спокойствие питерской публики URL',
#  'USER USER USER USER волчара позорная но но но',
#  'а вот и первая гостевая победа динамо вместе с любомиром поковичем хауген красавец',
#  'USER ихихи с много еще экзаменов осталось',
#  'вот и закончилась рабочая неделя как отпраздновать ее весело URL fact ireland odessa URL',
#  'USER это без сомнений но будильники реально работают раз через раз пора на wp переходить',
#  'rt USER от новости про виталика мы были в шоке d теперь я точно поняла что я лох',
#  'вся в ожидании оксана упала голой на кровать и обалдели от такого и муж и мебельный салон',
#  'как же это ахуенно спать до 12ти не сложилось на подп дойти',
#  'уезжаю регина все будет хорошо уже лечу кароч d',
#  'джефф красавчик спасибо USER за онлайн трансляцию всех с победой',
#  'rt USER завтра в 33 гимназии новогодняя ярмарка начало в 1 приходите',
#  'я не знаю но они были уже здесь задолго нашего появления follow',
#  'USER боюсь пересказывать это было бы сложнее',
#  'USER у меня вообще такая тема что с любой стороны можно меня пнуть',
#  'наконец то на новый год мы увидим снег а не слякоть',
#  'если написать слово ватман то 95 людей прочитают его как бэтмэн',
#  'rt USER кому надо повангавать какие у вас трусы обращаетесь к моему папе то есть к дурьману',
#  'ахахахахахаахахахаххахааххааххахахааххахахахахахазпзмхахазпзаахмзазхапзах я оригиналеееееееееен азпзщааззпаххааха d',
#  'ура переписывать будем в пн значит можно подежурить',
#  'афигенно все начиналось первые смс ки цветы мишки поцелууи а сейчас сидишь и понимаешь больше этого не будет да и не надо будет еще лучше',
#  'rt USER объявление века URL',
#  'вот чем я пахну после ванны запахсчастья URL',
#  'лит ра с русским тоже была збс d смеялись над всякой фигней ахаха',
#  'rt USER доброе утро дэласол и редман уууу URL',
#  'разговариваю с техподдержкой зенона остро вспомнился website is down d',
#  'rt USER USER пиздец хорошо пизошо запомни d',
#  'мы с удовольствием будем смотреть донецкий шахт р и не в тс павлик',
#  'мне сегодня приснилась песня я ее не знаю и помню только одну строчку он был отлитым пиратом к чему бы это',
#  'USER у нас учительница болела не успели пройти программу',
#  'rt USER охуенно замутил URL',
#  'USER сам придумал или опять сборник анекдотов прячешь где то',
#  'только сейчас с трени пришла на улице наступила настоящая зима красотень то какая',
#  'USER какая разница этого не должно было тут быть d',
#  'покупал сегодня кое что в топшопе для сестры все девушки вокруг смотрели на меня с максимально мимимишным выражением лица такнеловко',
#  'rt USER USER вам пора переходить на ios сир',
#  'rt USER для тех кто проснувшись читает тви уфа на улице снежно и минус 1 градус по цельсию не скользко и движение машин вялое',
#  'наша гордость родного лицея маоу лицей интернат 1 г альметьевска URL',
#  'USER лишь бы она ни передо мной сидела и ни за мной d а откуда у нее тяга к обществу проснулась d',
#  'USER это уже просто так с тобой за компанию',
#  'rt USER кажется это может быть полезно надо будет почитать при очередном раунде битвы с натом',
#  'USER я в последнее время в школе вообще не появляюсь а на этой неделе всего на 5 уроках была плюс завтра не иду в школу',
#  'если бы люди могли сразу нормально разговаривать все было бы намного проще',
#  'rt USER USER с такими копчеными финнами мой дед в 1939 не воевал',
#  'он широко улыбался не давая ей пройти между как всегда заваленными на половину проходом она была рада блять',
#  'USER это да а я вот думаю брать ли на рождетство или нет',
#  'завтра потом в вскр утром на олимпиаду ууууууууууууууууу',
#  'USER доставили но не догадались заранее позвонить хорошо что родители по соседству живут',
#  'rt USER USER с днем рождения удачи тебе во всем з прости что утром не поздравила я просто еще спала d',
#  'USER та вообще пох на пробки никогда их не ощущал ведь я живу на правом берегу бичис',
#  'USER она к тебе явно неравнодушна это самые вкусные конфеты в моей конфетной практике',
#  'всем спать а то еще нафлудите тут пока я до работы буду добираться и рабочий день опять испортится',
#  'rt USER записались с USER на маникюр на 18',
#  'USER USER ну я как всегда опоздаю',
#  'USER правда я хочу чтобы робби вернули а то он в таком виде и вполовину не так горяч',
#  'rt USER классно потанцевали сегодня с USER d мне понравилось валяться на полу школы d',
#  'USER USER я так понял что будут решать или в запас или комиссовать',
#  'USER регенерация в действии анализы говорят что меня можно отправлять в космос я тоже подозреваю соматику',
#  'USER мне говорили что на труде залили уже',
#  'проводить встречи утром это прикольно контрагенты такие сонные слегка и можно их поразводить на допскидки',
#  'rt USER USER ааа дадада все верно',
#  'USER уж пожалуйста по возможности URL',
#  'rt USER дождались URL',
#  'уи женька во вторник скорее всего в школу приедет рада рада',
#  'USER ты только первую часть сначала посмотри',
#  'пачиму оо патаму шта я сказал URL',
#  'стоять в супермаркете и смотреть биатлон так проходит мой шоппинг',
#  'все же что то достойное в вконтакте есть USER gt URL',
#  'rt USER мой 6к мосвящаю моим любимкам USER мой гейский муж USER мой вечный собеседник USER и мой гитар уч',
#  'USER если только десницей роберта баратеона',
#  'USER она это что или кто ага для придания большего эффекта d',
#  'USER USER да норм еще подрастет не буду его гномом считать',
#  'после введения инвайтов nnm club похож на приратскую рпг',
#  'сегодня у одной крутой бичи день рождения USER поздравляю тебя с днем рождения будь самой самой счастливой красота море любви тебе',
#  'rt USER USER бридж у меня у самого интернет хреново работает с',
#  'rt USER USER USER да норм еще подрастет не буду его гномом считать',
#  'у крс секса нет родственного скрещивания коров не допустит программа сыбага мамытбеков URL',
#  'rt USER в новом клипе the fray засветилась кэндис аккола tvd new thefray',
#  'USER ну прости но для меня ты всегда останешься малаховой вероникой',
#  'еще раз убеждаюсь что девушек очень тяжело понять иногда даже не возможно но это и притягивает нас к ним',
#  'USER сплю абсолютно один даже без мягких игрушек',
#  'USER да я просто не буду больше писать надо будет вспомнит и сам напишет',
#  'USER URL бэктрейсы в продукшене какое уж тут нагрузочное also чем редис gt мемкеша для well кеша',
#  'сегодня познакомилась с димой из 5 класса он уже любит меня мне везет d',
#  'как снег пошол так и новогоднее настроение появилось',
#  'перепост жаль что на украину не послали URL',
#  'сплю такая на парте и со всех сторон подходят ребята я аж ахирелаа dd',
#  'USER что то вроде того но в любом случае роль у данилы интересная для него неожиданная',
#  'USER когда мы приехали в алмату нас встречал какой то мужик и привел нас на квартиру показывал там нам d',
#  'в 4 договорились с лехой максом валероном встретиться на лестничной площадке',
#  'малышка сегодня будем веселиться потому уже просто ну очень надо жду вечера с USER что котяра доедет до нас USER',
#  'USER вспоминаете вы все про меня только перед приездом',
#  'можешь так взрослым не смотреть URL с помощью USER',
#  'буду смотреть концерн земфиры в прямом эфире URL URL',
#  'USER а я лучше уже сегодня чего тянуть',
#  'ахаха у кого то инет открыт я сейчас дорамку качаю',
#  'хотела наконец отдохнуть и тут слышу за дверью топ топ топ и тут она уже на пороге в моей комнате d люблю ее lt 3 URL',
#  'офигенный день день позитива бегал как идиот целый день танцы офигенны хоть я и ракал но мне очень понравилось',
#  'yg вы все наркоманы черин ты вообще сволочь я вас всех ненавижу d лал',
#  'ну вот первый запротоколированный пчел есть не знаю кто ты но спасибо',
#  'первый экзамен 1 января а последний 23 удачно все ура',
#  'USER хахах ой и не говори мне даже об этом',
#  'если ты сидишь в кафе и в час дня пьешь пиво то на тебя все палят а в кофе на вокзале всем пох поздновато понедел то',
#  'USER в 11 ехал мело видимости не было про скользко я ничего и не писал',
#  'rt USER USER и на убирашки в том числе d',
#  'USER у меня они тоже в 22 появились с др',
#  'вова 3 спасибо большое ты мой герой сегодня',
#  'красота спасет омск а партнеры у нас эстеты URL',
#  'rt USER tkabber работает но страшный же он',
#  'USER а я еще в августе исправилась и начала говорит правильно d',
#  'rt USER USER зам нь бартаатай хол бсн ч заавал чи олоорой х рээрэй амжилт',
#  'но повар зарезал его специальным кошерным ножом и двор гостиницы потонул в крови ff follow',
#  'USER вася не веди себя как зануда мы же молодежь беларуси',
#  'наконец то скоро жрать пойдем целый день голодный',
#  'USER одна с половиной пара и куча сладостей что может быть лучше 3 ты как',
#  'только что прочитала рекламу по телеку требуется бабочка ахаха я охерела d',
#  'USER вроде бы не очень не знаю тройка лидеров из 25 шк и гимназии',
#  'мне сегодня приснилась песня я ее не знаю и помню только одну строчку он был отличным пиратом к чему бы это',
#  'USER нафиг такую жизнь имя другое взяла и зачем только придумала о себе историю я не знаю надо б ей написать да на землю приспустить',
#  'USER рад ага все замечательно вчера фотки делал',
#  'USER хлопц трохи перестарались 3 грудня',
#  'агмдгседгес у роджерины есть мое любимое стихотворение можно умирать спокойно',
#  'опилки в голове не только у винни пуха URL с помощью USER',
#  'rt USER как то так URL',
#  'а зарабатывал я на испытаниях лекарств teamfollowback',
#  'rt USER USER выздаравливай URL',
#  'USER ты уже второй мой знакомый шо хочет в норвегию еще есть один в швецию а я не люблю холод',
#  'rt USER я хамиль и раскар работаем URL',
#  'rt USER всем прекрасной пятницы друзья',
#  'а кто нибудь сможет подсказать хороших книжек по дизайну в вебе не себе',
#  'USER в моей группе та же фигня за исключением одного петуха',
#  'смотрю старые японские фильмы все таки они крутые',
#  'девушка тебя куда подвести я со злости отвечаю туда куда мне нужно даже бензина на маршр',
#  'кстати все равно мы молодцы наша группа заняла второе место в олимпиаде пиздюки первые с',
#  'USER незаконный оборот взрывчатых веществ и боеприпасов ок подкидываю',
#  'USER USER USER ооо тибетская смешная и вправду',
#  'бля мне в понедельник к врачу а я толька больше заболел d',
#  'игровые новинки sony пророчит триумф ps4 над предшественницей игры',
#  'шоколадные опыты USER URL',
#  'USER USER USER USER USER USER спасибушки p s только заметила форэвэ слоу',
#  'самое печальное что я даже имея повод причины и мотивацию не могу тут страдаки разводить это так грустно d',
#  'rt USER а какой у вас способ подготовки radiorecord URL',
#  'USER ну хорошо как скажешь гей тебе лейка придет ну а мне',
#  'USER психолог спросил бы и в чем это проявляется',
#  'USER блин ссори я просто от радости все позабывала с я сейчас как дурачок по квартире бегаю и одеваюсь d',
#  '5 когда кончились все деньги а тебе надо платить в т ч по большому кол ву судебных трат и на ребенка это страшно хочется в тюрьму',
#  'гороскоп для всех на выходные смотреть видео party hustle hustlehard URL',
#  'смотрите как нужно рисовать на планшете прикольно да URL',
#  'после школы делать нефиг webcamtoy URL',
#  'USER ахаха суровый кеп пустил свинцовую слезу',
#  'у меня опять полный рот крови ска бля она вкусная',
#  'рождественский дизайн стаканчиков от kuzina nsk christmas kuzina URL',
#  'разоблачение серега еронин купил на подставное лицо очень дорогой немецкий автомобиль подробности позже',
#  'что я сделала с пальцем у меня он весь в синяке и опух',
#  'rt USER а куда пропала моя любова кохана хорана я ее уже минут 2 в ленте не вижу',
#  'блин пол года ждала этого дня и все классно я увидела олимпийский огонь видела как огонь передали толоконскому',
#  'USER а я вот печатаю даже не глядя на клаву и буквы не путаю т к прошла от начала до конца курс соло на клавиатуре шахиджаняна',
#  'rt USER вот такая растительность в коста рике URL',
#  'я лемуром в сл жизни а слоном я в зоопарк не спрячешься а а я спрячусь я в какую жопу спрячется слон а я в травку я тебе только к травке d',
#  'USER писдес d я так ржал ахахаха курту явно нелься спиртное',
#  'USER миленько а меня не взяли в лайф поэтому я опять грущу',
#  'а это коллега он еще не знает что спалился в форсквере URL',
#  'rt USER тот момент когда все под контролем URL',
#  'мир мир d USER URL',
#  'мистер довольство площадь у м третьяковская URL',
#  'кто хочет шикарный объект вмф посетить хочу посмотреть как преодолевается все полосы защиты URL',
#  'rt USER писали кп всем 2 3 4 красавцы такие и главное никто с группы ни капельки не всплакнул ну правда нашли бы с чего рас',
#  'так что теперь я буду подписываться под твитами d глупо конечно за то если меня кто нибудь читает он хотя бы будет понимать о чем речь d',
#  'USER я тебе скину пришли свою почту плюс сегодня там черная пятница скидки большие на товар со скидкой',
#  'разобрал портфель после сесси в нем чужих вещей больше чем своих не забрали во время пошли на фиг я все выкидываю',
#  'не была здесь с 5 ноября а тут 4 фалловера два пиндоса какая то банда и моя подруга но им всем пох на мои писульки',
#  'у нас самая лучшая в мире школа ddd света нет ура ура ура ура ddd я тебя люблю детка даа dddd',
#  'хотелось бы разделить проблемы с тян на 1 нужно просто поебаться как ни крути и 2 нужен человек который был бы рядом с',
#  'говорили по телефону сказал чтоб шла гулять отлично d',
#  'USER иди против них бунтуй ложись спать',
#  'люблю когда в школе проверка главное сидите тихо и из класса не выходите математика',
#  'USER тык у тебе еще 33 человека есть поэтому не заливай тут d',
#  'и снова кулинарю десерт для моего маленького именинника',
#  'и вчера она меня спрашивает видела ли я новый клип бэнгов monster d',
#  'да все уже выложили такую а я еще нет я тоже хощуу так что вот URL',
#  'USER я уже пообещал ребенке что мы модно заклеим все ее наклейками в виде букв звездочек и всего такого',
#  'USER злой ты а ты знаешь кто с быком будет на афише когда вы приедете в краснодар',
#  'USER ну вот мария сам премьер занялся проблемой ржавой воды URL как думаешь получится у него решить ее',
#  'от делать нехуй с утром продолжаю приходить в себя севергорода URL',
#  'USER собираюсь пойти на фильм только ради тебя не мешало бы лишний раз полюбоваться злым пашей',
#  'USER lte это то которое работает настолько криво что единственная польза от него это скорейший разряд батареи USER',
#  'USER дай знать что получилось по сайту а то я не могу достучаться',
#  'rt USER у дочки айфон у сынаандройд у мамы айпад а упапы айхеренный кредит',
#  'rt USER мультитран под gpl о х у е т ь',
#  'USER я ему еще план съемочной площадки нарисую с расстановкой в камере d',
#  'USER спасибр чудо да постараюсь привезти',
#  'USER вот это по нашему таскать из жара чужими руками',
#  'это нормально что меня во втором часу ночи тянет что нибудь покушать пойду йогурт выпью с булочкой чтоли',
#  'сижу на ярмарке в тви o v пропущу 2 урока и домой ура ура ура',
#  'rt USER хочу уже поскорее субботу URL',
#  'то прекрасное чувство когда лежишь в теплой кровати с едой телевизором и бездельничаешь полдня',
#  'спортивный алкоголь официальное вино fc real madrid URL',
#  'этот голос всегда услышу d кирилл хоть бы подошел вместе бы побегали а то как будто никогда и не знали друг друга',
#  'а вам уже знакомы фразы cnfnecs ghbdtn rfr ltkf xt ltkftim лично я их пишу постоянно',
#  'бывшие лучшие друзья бывшие лучшие щас как будто вообще не знакомы наверно это на пользу URL',
#  'rt USER USER хорошо же чтоине наоборот а где ты взяла абрикосы зимой',
#  'чтобы нормально поработать нажмите сейчас крестик в правом верхнем углу',
#  'у вас что с кириллом костюмы спортивные одинакавые ахах да только я штаны просрала в шк URL',
#  'rt USER USER гордость на всю жизнь d',
#  'USER USER мне тоже в плену то я его и полюбила правда чуть меньше собачек',
#  'USER ахахаха огооонь как там твоя малышка поживает dd',
#  'когда поешь вообще не работается тем более в пятницу',
#  'хорошего вам дня тви радуемся пятница же URL',
#  'ахахпхавхазах глеб гипнотизировал меня пакетиком чая dd география хули',
#  'олимпийский факел таки погас новосибирск сочи2 14сибирь URL',
#  'крутой видос насть я прям поржала d особенно на вопросе о сумерках когда они руки приготовили а потом отдергивали d',
#  'USER не ссы малая сустрэнем зимушку в щчучыне',
#  'rt USER мы с USER пошлячки еще те',
#  'ребята городской парк культуры и отдыха им м горького URL',
#  'USER это просто плохо видно ты не видео что вчера было яб сфоткал но она забинтована с',
#  'USER ха вы всегда крутые то какашками обзываетесь то чмо и тд',
#  'rt USER USER собираюсь пойти на фильм только ради тебя не мешало бы лишний раз полюбоваться злым пашей',
#  'USER клип хороший сергей вы молодец ждем на дальний восток и сахалин',
#  'USER и че а тебе скоро 15 и ты в восьмом классе',
#  'жизнь моими глазами хорошее вино согревает URL',
#  'какие то странные скулы у меня но мне нравиться URL',
#  'rt USER ахахаха я не сдержалась d URL',
#  'и я короч сказал ей что в другое время не могу и отменил занятия',
#  'USER не знаю пивасик не знаю так обходиться жизнь d я сейчас пойду в место где я счастлив d и не был уже 2 недели',
#  'USER USER USER если подпишут с тс то толковая молодежь буде убегать заграницу массово и заметьте не в россию',
#  'USER главное адекватно высказывать это мнение и адекватно воспринимать иное мнение',
#  'с бабушкой так мило поговорили что же я ей раньше не сказала блин',
#  'USER а певец то замечательный певец а еще и композитор',
#  'USER лал сорри тогда d ахах ну ты молодец эт классно с',
#  'USER ааа бо ты сказала чтобы я добавила таки да',
#  'USER хах я очень хорошо ыыыыыыыыыыы ты как',
#  'rt USER выздоравливай URL',
#  'USER ох как же хорошо что вы все есть 3 кстати давай там провожаю тетю ирму и топай в школу d сейчас поколдую шепатадаааа',
#  'ура ура ура поздравляем победителей творческого конкурса моя любимая игрушка от рела лайф 1 URL',
#  'rt USER ie с версии 9 platform preview 3 стал поддерживать canvas не прошло и 1 лет',
#  'rt USER USER можно и конкурс устроить',
#  'USER ну репа же до 2 а концерт в 21 только начнется я не забываю',
#  'ржу че за USER знаки с которыми не стоит шутить о сексе могут и согласиться 5 скорпион лев близнецы стрелец',
#  'хороше настроение теперь на весь день почаще бы так',
#  'rt USER краснооктябрьский сасааайтееее',
#  'вакуумный пакет для хранения вещей крутая штука так много места в шкафу теперь URL',
#  'во многих вариантах жеребьевки нам аргентина выпадает неужели она все таки будет и опасно и интересно',
#  'USER надо сразу в африку там можно босиком круглый год ходить',
#  'USER мы выбирали из 3 отелей и этот был ближе всего к офису',
#  'всем поклонникам смиксера рекомендую взглянуть на его сегодняшний дудл w w главную страницу',
#  'котаны кто хочет выйграть денег и составить конкуренцию другим командам go играть URL',
#  'буду искать человека чтобы сдавать 2 комнату или уговорю катьку жить со мной уборка на 2 постоянная компания',
#  'кто то в углу сидит и погибает от голода а мы еще 2 порции взяли хотя уже и так жрать не хотим dd URL',
#  'USER заходите к нам в группу в папке в наличии есть много всего и мы встретимся с вами максимально скоро нешутим',
#  'USER да ты чооо этот сериал просто воплощение всех яойных мечт',
#  'USER дыа дисней и муз тв обожаю оо',
#  'USER это как то неинтересно и ни к чему не ведет',
#  'USER хах да ты экстрасенс прошел час и у кеши активность вверх пошла mtvstars 3 seconds to mars',
#  'USER между янги абадом кадышева и панельным езжай USER',
#  'одни варешки каринке отдала вторые илюха забрал емае в чем я ходить то буду d',
#  '5 минут назад узнал что есть такой коллектив как pendulum и что 17 они будут в ебурге колбаса',
#  'какой будет эта зима зимней d URL',
#  'have a nice day хорошего дня с н е ж н о е URL',
#  'USER USER USER да норм хд она план строит злодейский но это секрет',
#  'каждый день я убеждаюсь в том что я не ошиблась с выбором кумиров деми спасибо что ты есть URL',
#  'rt USER люди не травите крыс мышей и прочих хвостатых няшек ведь они залог нашего пищевого изобилия в будущем',
#  'USER хаха океей если снова обидятся то это уже будет замкнутый круг выход из которого улыбнуться и не обижаться',
#  'я поняла что я не знаю где проходит лекция по матану',
#  'USER добрый день там что колокольня в полном размере',
#  'USER и да ретвит бы не помешал заранее спасибо',
#  'USER USER USER это не заразно не надейтесь',
#  'взрослая жизнь это когда марш домой кричит не мама а муж',
#  'да влюбилась я в нее лаки умница славная девочка и внимание что немаловажно у нее хороший URL',
#  'USER USER а я се пару футболок и толстовочку заказал вот только гемор с доставкой',
#  'это приятное чувство когда тебя ретвитит USER',
#  'USER просто у шефов есть свой тайный язык на котором они разговаривают между собой чтобы никто не мог догадаться об их намерениях',
#  'rt USER USER хорошо что делаешь',
#  'rt USER дело было вечером maxstomatolog и vadimgurko ехали к USER по очень важному делу URL',
#  'возрадуйтесь хохлы вот вам толерантная европа',
#  'USER совет переговорить с депутатами включенными в эти пресловутые комиссии является попыткой переубеждения неожиданно',
#  'USER могу научить я регулярно пишу письма сама себе чтобы дома работать кира взяла с меня пример',
#  'USER мр я зол и трагичен в целом но сейчас все окей мне весело х когда мы встретимся',
#  'чуть не кончил пока держал руки под горячей водой d',
#  'ееееееееееххххххххууууууу сегодня я стану тетей 6 декабря год змеи стрелец я так рада URL',
#  'rt USER напомнило некоторых URL',
#  'мужские ноги выглядят непривлекательно в косметической рекламе даже усыпанные цветами',
#  'USER есть в нашем славном городе места х',
#  'awesome lt 3 трахнул друга в жопу URL',
#  'USER ну херли нет то и на маках у нас винда стоит все как и должно быть',
#  'rt USER жолиг з рхлэн зурах гж оролдов URL',
#  'rt USER люблю когда прикасаются к моим рукам посекрету d',
#  'rt USER советую почитать занятно оверклокни моск 111',
#  'origin сам добавил fifa 14 мне в корзину что плохо продается',
#  'сдал последний экзамен 6 экзаменов из 7 на отлично и одни на хорошо остался 1 зачет и практика',
#  'USER USER хорошая зарплата если с нее можно вот так купить хороших телефон чтоб еще и на жисть осталось',
#  'rt USER вся илитка собралась URL',
#  'USER ура хоть кто то ответил d и тебе добра',
#  'USER для просмотра с девушкой пойдет',
#  'USER USER USER она меня любит',
#  'rt USER пошел гулять с собакой забыл собаку дома хорошо что мама напомнила взять ее с собой d',
#  'да какого я такой ватный то сегодня еще 4 часа и отпуууск',
#  'ну ты сережа вообщеее dd 2 день подряд на уроке у тл говорить такое dddd',
#  'rt USER я разбил пять машин и мне ничего за это не будет d',
#  'USER эта да я воть кстати тибя сразу узнала ага',
#  'rt USER я по прежнему утверждаю что lie2me вытягивает исключительно заставка',
#  'еее завтра после школы гулять жду нашей встречи',
#  'USER может лучше подскажешь какие библиотеки вы использовали',
#  'вот чем я занимаюсь когда беру 5 1 минутный перерывчик на работе URL',
#  'USER ты действительно хочешь совершить это маленькое безумство',
#  'USER USER хаха вы меня совсем заинтриговали кстати худшая серия была про муху невыносимо просто',
#  'rt USER а на вулиц снн г маленький правда но',
#  'USER USER скорее всего поехали вика поправит',
#  'rt USER гоню гоняю музыка орет все как я люблю',
#  'rt USER соколовскийяхочутебя что я к тебе на ручки хочу канееееееееечно URL',
#  'USER н чого я так живу всьо норм звикнеш або все буде добре',
#  'сегодня четкий день в школе был можно сказать было только 4 урока на остальных тупили',
#  'круто в пловину 11 го приехали и уже домой самый быстрый день в школе',
#  'rt USER надо проверить свою ноклу 6131 на совместимость с огг',
#  'к грядущему концу света они выпустили забавный набор в который вошли спички шоколад анисовый ликер нож блокнот и питьевая вода',
#  'оказывается есть миранда комьюнити и в израиле не знал перерыл там все думал найду все же жаббер сервер поближе чем',
#  'яааасан гояын ккк USER тарчлаа шдээ tgif н д р дан 18 йлдл д хийнэ ээ гэсс',
#  'цитаты великой милькоты как жирзнь как жир а я зимую',
#  'rt USER оле сигну собираемся делать у нее на груди вдв хули d',
#  'ff ru сегодня был жесткий день посмеялись до слез',
#  'срочно всем альбом skillet rise всем в уши нечто skillet',
#  'USER лови так можно и руку до горячки довести d',
#  'за эту неделю наприходило URL',
#  'USER видно что в вечернем платье ты себя намного уютней чувствовала ты молодец',
#  'карманная катяя ты знаешь что делать идем к расписанию значит англ у тебя да будем ходить по 2 этажу',
#  'USER ахаххахахах ну надеюсь он сможет dd',
#  'здравствуй бабуля я анастасия URL',
#  'опишите меня в трех словах на trislovamne ru URL',
#  'rt USER да да наконец на каток я по нему так соскучилась',
#  'USER USER климы понимают друг друга',
#  'мы с юлей нормально не можем вместе свалить нас полюбому запалят все преподы',
#  'меня посадили в жюри на вперед мальчишки это будет весело ddddd',
#  'USER мне бы знать еще какие приседания делать если знаешь подскажи',
#  'rt USER аленка назвала женю малышка d',
#  'я начинаю догадываться зачем ученые затягивают окончательное решение вопроса бессмертия',
#  'USER оо я с большой радостью заехала бы',
#  'у пацана не получилось поделить конфету в ход берется его младшая сестра ахаха d',
#  'вчера посмотрели фильм меня зовут кхан мне очень понравилось советую',
#  'мы медузы мы медузы мы похожи на арбузы пиздец полнейший',
#  'rt USER я и не знала как сильно настя доебывает другу настю в твиттере лехче насти воу воу',
#  'USER замечательно сделали отменив уроки в субботу',
#  'паша было весело очень рада что познакомилась с этим человеком URL',
#  'USER везет но не то што в школу в пон а то што ни че серьезного',
#  'по магазинам сходила продуктов накупила начинаю готовить хозяюшка прям',
#  'я заметила что обожаю рисовать каликатуры они выходят у меня милыми и смешными',
#  'USER мне просто еще ехать надо из этой дыры но мб родители докинут',
#  'USER следующий шаг что быстрее кол во читаемых 777 или твитов 5555',
#  'USER и USER вы у меня такие хорошие девочки',
#  'USER ахахахххахахахахах ну ермаков меня на биологии порадовал',
#  'немцы вдули аргентине 4 я не фанат но даже сам прозрел',
#  'двойная реклама записывайтесь на шеллак ко мне или покупайте жевачку love is у bukatchuk URL',
#  'USER между прочим нормальная я все жду уогда мне стукнет 2 и я сменю паспорт и фотку на нем',
#  'киса помогать любит хватать ленту от рулетки d URL',
#  'USER льстят только постоянные продавцы постоянным покупателям которые стараются не менять магазины мне в этом плане повезло',
#  'USER разработка корпоративного стиля на примере телеканала ю',
#  'химия я не напрасно писала потому что получила 4 оно того стоило о даааааа URL',
#  'rt USER USER российские дипломаты в сша URL',
#  'rt USER USER билет в киев 1 грн поужинать в kfc 75 грн поучаствовать в свержении режима бесценно',
#  'rt USER ахах USER пытается что то до меня донести а я толком и не понимаю х',
#  'если на душе скребут кошки не вешайте нос придет время и они будут громко мурлыкать от счастья',
#  'USER 12 туда в 8 утра обратно 21 в 2 3 кажется',
#  'USER USER USER это хорошо для нас что к италии не попадем или ты переживаешь что папо рашку в игре не увидит',
#  'тогда узнаем кто прав а кто мертв ru ff ff ru followback',
#  'а теперь поговорим реально d все трейни подписывают контракт в котором есть пункт который не позволяет им рпзглашать личные данные компании',
#  'скорпиончики молодцы 1 е место день удался d URL',
#  'USER а USER у нас профессор латыни',
#  'я понимаю что я выросла и не верю в деда мороза но а в друг случится чудо и он прочитает мое письмо URL',
#  'rt USER девки кто за то чтобы хачи перестали уже нас палить ну реально стремно както d',
#  'rt USER USER USER ну типа того хотя я за самый жесткач только молодость только хардкор тем более на чм2 1',
#  'мммммм у столицы на онего новое любимое словосочетание власти петрозаводска и власти карелии',
#  'USER USER ахахахах не он сам ее откроет ии бежим в разные стороны',
#  'его тут распирает даже покраснел и задыхается ddd ахаапахахпаха',
#  'офигенный день день позитива бегал как идиот целый день танцы офигенны хоть я и ракал но мне очень понравилось',
#  'как воспитывать детей кнутом и пряником URL',
#  'USER USER хм ну подумай d еслитыпонимаешьочемя',
#  'rt USER USER с днем рождения 3 всего тебе самого самого будь счастлив всегда',
#  'rt USER цитаты великой милькоты как жирзнь как жир а я зимую',
#  'он вроде как запал на нее как я слышала ru ff',
#  'это что у нас новенькая в классе d нет нет нет d все для вас',
#  'rt USER жиргээ р оронгуут л сайхан мэдээн д урсаж байна ямар сайхан юм бэ сэтгэл сэргэчихлээ',
#  'я приехала крым хорош красив но далек теперь от отпуска надо отдохнуть бы',
#  'я да пошел ты USER ээй успкойся что он сделал даша ируу обидилиии пошли ананасу жалаватся d',
#  'получить комплименты от таких дам это жесть как приятно',
#  'USER хаахах ты плакала из за математики',
#  'ахах девочки как дебилы пионеры зеленый галстук розовые ленты а так норма',
#  'бл от семок уже язык щипит пойду заварю роллтона ddd',
#  'rt USER URL а ну вот держи гы',
#  'USER USER USER модные леопардовые угги за 6 о чем вы URL',
#  'все у меня чемоданное настроение собираю вещи еду домой',
#  'самый быстрый кабриолет в мире интересно сколько будет стоить',
#  'USER ключевая фраза была кто хочет дать небольшое интервью по этому поводу',
#  'поехала к сане в студию сегодня делаем фотографии ну или просто выпьем и поговорим л вечном',
#  'rt USER елка такая красивая у нас в школе',
#  'USER прорыва на внутрь или на вне',
#  'USER интересно а может да прийти к нам на концерт тоже хотим такую рекламу чем мы хуже yotaphone',
#  'rt USER shoro URL я хочу плакать сс',
#  'rt USER супермодель жизель бюндхен приучает сына к утренней йоге starlook fashion amp beauty мода и красота URL',
#  'ооо лайки теперь в новостях сердечками обозначаются ох уж эти преобразования',
#  'USER хочу успешно сдать егэ ну и поступить на бюджет куда хочу твитдедуморозу',
#  'USER мы этого ни в коем случаи не допустим',
#  'а настроение то хорошее всем улыбок и добраааа URL',
#  'артур идиот на весь класс на уроке петь начал ахах',
#  'кто то один поставил лойс лента такая отзывчивая я прям ору либо не нравится никому',
#  'ребята не забываем про клуб в межсезоночке придумывайте идеи для развития движа пока есть время URL',
#  'USER год и дату рождения за одно спроси уж тогда',
#  'USER пока вы искали клубничку чудесным образом закончилось вино повторить надо USER',
#  'собираюсь лететь во флоренцию сегодня полна энтузиазмом я в предвкушении',
#  'USER не могу чтоб не сказать слова похвалы можете развеселить спасибо',
#  'USER ну лаадно поной все станет лучше у меня отвратительное настроение я зла сделай скидку я тоже ною все ноют',
#  'кто знает когда выходит свежая серия на канале тсн евромайдан новая общага янык посидит на ручках у путина в сочи',
#  'это зеркало популярное просто d URL',
#  'USER или быть им эксцентричными пародистами те что радуют себя в зеркале',
#  'USER тут блин что одно то другое стреляет плохо и вообще состав известен на эстафету',
#  'задайте мне любой вопрос на trislovamne ru URL',
#  'проснулся сегодня с настроем бешеным написать текст на трек flow с одноименного микстэйпа посвящаю день этому треку',
#  'USER USER это все потому что он хач',
#  'USER с премьерой клипа сереж свои впечатления я уже написала клип сильнейший и спасибо за эфир подняли настроение как всегда',
#  'спасибо за то что сделала из тупой умною прости за нервы спасибо кс URL',
#  'USER да это подруги моей она в остине покупала',
#  'последний день лета прошел как то странно пол дня сидел дома занимался херней погулял с подружкой проводил друга все норм',
#  'USER да не за что желаю тебе здоровья',
#  'USER USER в знак протеста за необоснованные претензии руководителя я посмеялся и был уволен он дослужился до пенсии',
#  'березка praematuris homicidiu на берегу цимлянского водохранилища в волгодонске URL',
#  'USER обожди солнце зайдет все наладится пятница же',
#  'ахаха ну только надя может сьесть суши с 8 раза при этом разлить соус а потом вытереть его чеком d',
#  'настроение ааахеренное особенно после английского спс пиздюку',
#  'USER зазаза d я буду ржааать над тобооой так же как алина надо мноой вахахахаха d',
#  'rt USER праздник последний урок с ингрид URL',
#  'устала так скучно жить хоть бы в школу пошла нет блять сиди дома',
#  'USER да биллу ваще явно абы туц туц записывать судя по исполнителям которых он слушает х',
#  'алинка вот это правда было неожиданно но мне приятно очень спасибо маленькая моя за воспоминания URL',
#  'USER если бы меня уволили мне бы не хотелось пить',
#  'USER а мне не нравятся они вот и все',
#  'история с смс уже на первой полосе халявной газеты метро',
#  'сходила в школу еще раз услышала что мы были самым лучшим выпуском здорово',
#  'USER счастье птиц заключается как раз в том что они не думают в отличие от нас',
#  'rt USER все остались довольны и болельщики и главные герои URL',
#  'USER ну с возрастом она стала явно лучше URL',
#  'зашла в аудиторию как получила под кофту снежка от оли пупач спасибо',
#  'они уже закладывали бомбу в том месяце я тебе отправляла видео или нет USER',
#  'ура практически все долги по инглишу сдала один пересказ только остался',
#  'rt USER USER да да да он в феврале писал про песню с пианино гитарой и голосом билла',
#  'когда стараешься понять человека а не критиковать и злиться жизнь весьма упрощается попробуйте',
#  'теперь я рада что у нас был 4 й класс какие они хорошие нафоткались с ними обязательно буду приходить к ним в гости URL',
#  'кстати это я заказал сегодня снег для USER чтобы она в своей день рождения чувствовала себя хорошо',
#  'а у нас наконец то все хорошо любовь и взаимопонимание курим трубку мира',
#  'USER USER USER USER USER USER он так аккуратно лапку вытянул умора',
#  'rt USER боря бой стыдно самая охуeнная пeсня',
#  'trancefamily я уже определилась с моим futurefaborite а как насчет вас URL',
#  'rt USER ооой это же яяя d URL',
#  'как же хорошо быть с тем кого ты реально любиш',
#  'зимой нет ничего лучшечем одеяло чая с лимончиком и печенюшек',
#  'rt USER USER пади от вибрации оповещения d',
#  'не сказать что сейчас люблю но точно не напрягает еще одно умение которое все любят восхвалять как нечто героическое',
#  'USER на необитаемый остров я бы все же предпочла более цивилизованное пмж',
#  'приоритеты приоритеты но боже мой как это круто обожаю свои новые возможности и обязанности',
#  'а на работе уже праздничное настроение URL',
#  'как ты ее от других корейцев отличаешь да у нее глаза большие улыбнуло',
#  'сначала еду к любимым в шкалку потои к гавру в гости',
#  'с днем рождения USER морожку и единорогов',
#  'USER вчера слушал тоже в машине старый рок вечен',
#  'привииит линта похвастаюсь у меня по контрольной по русскому пять танцевала как огурчик dd',
#  'rt USER проверять регился ли ты на сервисе через восстановление пароля на почту извращение какое',
#  'сегодня сделала очень доброе и полезное дело и от этого кайфую',
#  'USER не расстраивайся кать гоголь будет круче d',
#  'завтра в школе джинсовая пати все очень модно будет',
#  'USER приедь во владивосток d ждем азаззаза',
#  'скрин моего тви в паблике хуеваядевушка успех епта d',
#  'мама хотела чтобы егор со мной поехал в кз но я пзвонила брату и он сказал что будет с друзьями по этому я еду одна',
#  'чему бы грабли не учили а сердце верит в чудеса',
#  'еду за новогодним платьем и новогодними подарками моим родным и близким',
#  'rt USER жиргээ р оронгуут л сайхан мэдээн д урсаж байна ямар сайхан юм бэ сэтгэл сэргэчихлээ',
#  'USER патрюш можешь помочь ретвитом если не сложно конечно',
#  'USER о если покормили еще то это вообще супер лол d',
#  'USER ахах даа а последняя часть ему больше всего понравилась',
#  'USER ну я как бы не настаиваю но буду очень рада',
#  'rt USER только илюша читал учебник URL',
#  'USER я вообще не ожидала что маха способна на такое маш не в обиду',
#  'USER USER да кто ж говорит что они не нормальные замечательные даже',
#  'rt USER это так мило URL',
#  'rt USER спокойной ночи с волей милый классный воля прекрасный URL',
#  'надо у елены николаевной спросить где можно психолога найти',
#  'USER хаха рождество наступило раньше в этом году d',
#  'ты красиво одеваешься и кудряшки крутые я так не налюбуюсь тобой URL',
#  'USER а USER не писала про хороший телефон заметь USER',
#  'rt USER заходил сегодня на работу меняли свитч портов как всегда не хватило',
#  'USER USER похудела и очень похорошела так держать',
#  'USER не менялся но он жутко глючный уже так что мог и не получить спасибо тебе',
#  'кто то решил попиариться на удалении канала ello',
#  'rt USER ееее URL',
#  'вааау foursquar обновили под ios7 красивоо но непревычно',
#  'rt USER а ты толстой не станешь пожрем увидим',
#  'последнюю серию молодежки на этой неделе я смотрела на одном дыхании',
#  'USER всегдаUSER бывает у меня часто очень ого что выбрал то и имеешь',
#  'янукович пролетит над украиной URL',
#  'USER урчи громче день еще не закончился',
#  'у нас тут в петергофе апокалипсец каин то все задуло снегом я начал подозревать неладное когда увидел что забита снег',
#  'переписываюсь с дашкой любит же меня d сучка тупая 3',
#  'USER ахах а что нравятся да я не открою тебе эту страшнейшую тайну ахах да в контакте d',
#  'USER USER измени установку должно быть отлично',
#  'USER USER ну вы вдвоем идите как раз',
#  'просто невероятное настроение с занятия басом вытаскивают из депрессняка',
#  'офигенно погуляли детство вспомнили в снегу повалялась пришла домой как снеговик',
#  'rt USER ссылка на текст о микролитературе это должно быть тут',
#  'богдан старается по цветами складывает карандашики URL',
#  'rt USER rt продвижение сайта URL от компании профи russinapromo мы вас ждем с наилучшими пожеланиями URL',
#  'USER физматы вообще мало чем различаются',
#  'USER самый болючий вылечила еще 2 и белить их буду',
#  'USER USER даха ну ей же надо поныть',
# ...
#  'ооо началась война цен на e ink устройства радует',
#  'мне иногда хочется чтобы у меня были сиськи нет ничего такого просто руки иногда девать некуда dd',
#  'rt USER цитрон я не дам тебе пришить мне яички',
#  'кстати муж прости что не ответил сегодня у меня мани кончились d',
#  'вова сидит и ногами бултыхает а со стороны не так понятно а я спросила наяриваешь ахах и все в упадке d',
#  'кирова позвонила и плачет в трубку после того как узнала о победе и как я только понимаю что она мне говорит сквозь слезы vixx1stwin',
#  'вот это нооовости оличноооо самое главное чтобы получилось все',
#  'обоги мой чудесный сосед слушает ани лорак на всю за чтоо d',
#  'опааа нашлось фото с глендейла ахахах URL',
#  'carnival phantasm все адов ебаный пиздец ржал как конь сэйбер в роли служанки ваще пиздец',
#  'а че никто не обсуждает апдейт pr URL ruseo ru seo google тире заменить на точку',
#  'rt USER ты не поверишь какие сексапильные очешуенные парни у меня в комнате опять плакаты купила d дааа о',
#  'USER и еще привет я если ты не забыла хаха я сейчас одеваться буду',
#  'USER USER все эти цифры и разноцветность вызвали ассоциацию с паровозиком томасом',
#  'лучшая мотивация для занятий алгеброй URL',
#  'пятница вечер и снова отмечаем URL',
#  'USER USER у меня школа без медали универ без корочки и жизнь отличная не скучная причем твоя медаль к отличной жизни есть связь',
#  'USER у тебя сразу массаж сердца получился у меня ручонки слабые пришлось прыгать на максютке чтобы хорошо надавить',
#  'в современной жизни действительно так URL',
#  'USER успехов тебе у меня такие же планы только позаниматься еще хочу',
#  'USER как стрелец стрельцу желаю больше халявы ю ноу',
#  'подарок от юльки когда отдавала сказала что я в жизни няша улыбаша скромняша и т д URL',
#  'USER я узнаю об этом только если постигну учение дзынь мынь но такого не постичь поэтому буду думать что все таки шейх',
#  'USER приеееет 3 давно не списывались как ты хоть поживаешь моя сосика в тесте',
#  'уехала в деревню спонтанное решение родителей меня радует',
#  'rt USER катя возьми телефон это он это он звонит d соколовскийяхочутебя',
#  'люблю безумно с юбилеем старушка обожаю тебя URL',
#  'USER сойдет но хочу лучше сесссия скоро нужно готовиться учить веселые выходные намечаются',
#  'USER эти строки даж в тексте материала есть',
#  'USER URL смотрится гораздо красивее купленных нами бкмов не правда ли',
#  'ахаха ребят это была лучшая репетиция пьяный мужик на кублуках доволен d',
#  'USER если ты там конечно будешь могу к тебе на неделе подъехать',
#  'вечерний город красивый без пробок бы еще добраться до дому',
#  'счастливый обладатель iphone 5c URL',
#  'дома всегда хорошо даже с этой идиоткой URL',
#  'нет не холодно зима щ1ы1э л1о вмашине жду минутнаяскука трц россия URL',
#  'сдала документы на визу надеюсь в январе попаду сюда URL URL',
#  'ахахахах ты чо ахахахах да успкойся ахахахха да ты достала ксюшааа ахаххаххаххаха и вот так всю дорогу с аллой d',
#  'USER конечноооо я заставлю его там появиться',
#  'USER ахаха д вочка ти шось попутала ранеток слуха ш ти а я слухаю аху нн групи до яких тоб ще рости рости',
#  'когда ребенок говорит мама еда в холодильнике в интернете долго не не сиди можно упасть со стула',
#  'настя пиздит от бога когда говорит что она уже вышла из дома d',
#  'USER благодарю и вас с праздниками грядущими',
#  'впереди выходные и мы желаем всем студентам провести их максимально ударно и помните session is coming',
#  'rt USER обсуждаем тех кто поступает в пед d',
#  'началось USER USER URL',
#  'USER такой у меня такой же был URL',
#  'rt USER еще 5 месяцев а уже сегодня сидели о дойчланде во всю мечтали',
#  'отличных выходных друзья URL',
#  'USER у меня примерно так же но фу в прошлом году 73 было а тут сложный бред дали фе',
#  'мой безумно обожаемый брат USER наркоман',
#  'USER я думала сейчас будет что то вроде шутки про кропотова да нет просто давно так сложилось',
#  'USER вот так ахаха правда спасибо огромноеее',
#  'начинаю уроки делать их мало вот поел таиландские фрукты',
#  'даже не знаю буду ли сюда выкладывать скрины игры но трейлер точно выложу d как будет готов',
#  'rt USER пс кстати 1 дней до мельбурна чтотобудет',
#  'USER а зачем ему он теперь политик',
#  'первый рабочий день в регистрационной палате прошел на ура очень дружный и веселый коллектив',
#  'USER и USER ребята поздравляем вас от души любви вам и гармонии молодцы',
#  'накануне водитель говорит что нет у него ощущения праздника а у меня есть новыйгод',
#  'USER не знаю и знать не хочу смылся куда то d',
#  'USER 1 с бараном перепутал 2 орел и решка 3 птица тату',
#  'USER ученые кофе приносит намного больше вреда чем пиво не рассказывайте об этом никите',
#  'она думает что квартира принадлежит ему о instantfollowback ff ru',
#  '5 причин перестать нервничать 1 нафиг надо 2 нафиг надо 3 нафиг надо 4 нафиг надо 5 нафиг надо',
#  'USER истанбулд явжээн энэ USER тэй',
#  'очень крутые ребята только качество не очень citylights URL',
#  'женщина должна уметь делать 7 вещей 1 готовить и знать 69 поз URL',
#  'USER скажи ему что он слоупок и кароч накажи',
#  'USER USER дольше это больше',
#  'rt USER больше некуда писать все кавно в прорубь пхаха фантазии нет предела',
#  'близняшки такие стесняшки d я у темненькой спросил куда надо нажать в экселе она отпросилась в туалет со слезками dd',
#  'USER я уверена что дойду до первого босса и потом будет аааа помогите страшно d детские страхи d',
#  'USER и тут я забыл зачем пришел URL',
#  'rt USER правильный спидометр radiorecord URL',
#  'наверно в следующей жизни когда я стану кошкой я высплюсь URL',
#  'и я снова дома в своем родном городке я не думала что буду так скучать здесь все такое родное как в вс обратно поеду даже не представляю',
#  'USER ух и строптивая ты девушка d молодец главное чтобы потом проблем со сдачей не возникло',
#  'говоришь жуйк очередной аськокапец а и правда похоже только не на капец а на копчик вместо обычных 3 онлайн',
#  'USER в честь собственной невнимательности и необоснованного наезда пропиарю ща ваше исследование',
#  'приехали не давно все было круто театр оперы и балета очень красивый ребят группа поддержки спасибо вам большое было приятно',
#  'rt USER USER как путин не понимает че народ вышел искренне причем судя по кадрам',
#  'если вы хотите спросить по сербски что это говорите што е то',
#  'грандиозные планы на день прощай компьютер встречай друзей',
#  'rt USER а вот и фотка с тура 2 15 сергиев посад иваново мытищи серпухов наро фоминск люберцы d URL',
#  'заменяем все маты словом матан а смысл то и не меняется d',
#  'USER зависит от пола но губы тока эксклюзивно',
#  'rt USER USER спасибо большое я думаю один из лучших подарков это попасть вот в это место поэтому в хогвартс тебе 3 http',
#  'rt USER ваш девиз невозмутим возбудим и не дадим наш девиз еще мудрей не дадут возьмем блядей',
#  'ты мой тигренок ае обожаю тебя URL',
#  'ох хорошо пошли свете три снежки в голову ну а мне одна в лоб',
#  'ну ка зацените мою еще одну обновку URL',
#  'меня на изо сегодня раздавили расспросами про иртанцы',
#  'приятно слышать такие слова URL',
#  'USER ито святое всех святых я плакал тут из за серии одной поитому лицо опухлоо d',
#  'rt USER летим на авиа трамвайчике в белгород мои алтайскиесибирята на репетиции URL',
#  'USER аххаха ты небось за пару тройку часов приедешь',
#  'rt USER щас с аней пойдем навестить нашего больного человечка USER',
#  'вот я и дома метет канешно на улице то что надо и лед есть',
#  'USER USER вау круто отдохнуть жду встречи в смр',
#  'буду считать новую работу фев подарком к моему праздничку 3 и пусть это не так d',
#  'USER пхахахахпааха бушующие давай пали что тем у тебя еще есть на меня d',
#  'тяжелый выбор между парикхмахерской и кино или и то и другое',
#  'гг в качестве толстого троллинга на что идут любители фара чтобы доказать что он лучше',
#  'на улице необыкновенная погода так отвыкла от этого беленького пушистого хрустящего снега а эти большие хлопья летящие огромным потоком',
#  'оказывается avr32 это банально mips о как жаль что не sparc',
#  'USER USER добро пожаловать в команду d',
#  'раз дума вводить все больше запретительных законов может пора ввести закон на запрет на введение запретительных законов',
#  'USER кстати он тух несколько раз я колдовала все как ты и просила d',
#  'USER давай подтягивай народ к этой дикой тусовке',
#  'USER ооо наши грандиозные планы на каникулы',
#  'USER привет большой привет и персональный',
#  'поставила фото какого то немца тут же пачкой деффочки знакомица',
#  'rt USER USER даа мне тоже уберись и ляг милая',
#  'rt USER vevo сказали что мы первый фандом который сломал их систему d URL',
#  'учим чешский многие слова очень похожи на украинский',
#  'USER мне нет просто вопрос заинтересовал',
#  'USER d алина это такая честь познакомиться с котом камикадзе',
#  'USER казанцева яковлева щепаренкова мурина тарасова это все поздравляю еще раз с выпуском красотки выпускной2 13',
#  'а не пошел бы ты в жору сказала алена ну в принципе да пусть идет так даже обиднее',
#  'смерть на похоронах я серьезно это ржач ппц ddd еще хороший фильм тариф новогодний',
#  'rt USER прощай маникюр здравствуй огород d',
#  'про антинародный режим с шмидт объективно смотрит на вещи URL',
#  'я сегодня вечером зависаю в кафе bali на б дмитровке на акустике гр кейн приходите у кого есть время и желание начало в 1 вход free',
#  'USER USER USER USER USER USER USER мне пофиг не болельщик',
#  'начинаю готовить прогнозы инет домашний вырублен надо проплатить 3g спасает',
#  'USER аааа точняк dпхахахаха я тибе ещо не отправил на следующей неделе пойду с',
#  'rt USER ржу пздц ахаххаха бывает же такое сейчас такую аварию заснял я тебе перезвоню зая URL',
#  'пересмотрела видео с дня рождения фраза колодяжки USER ребят вы че не рэперы вообще сделала весь вечер',
#  'так обычно у меня проходит химия ну и немножко математики URL',
#  'USER USER USER USER USER USER его голос с ним мое сердце всегда поет URL',
#  'USER USER USER USER USER USER USER гээр юу байна',
#  'офигенный день спасибо всем кто присутствовал на презентации за него',
#  'rt USER USER татьяна лазарева приняла участие в проносе олимпийского огня вот это да неожиданно героическийпоступок',
#  'USER USER хахаха армаанчиг гэж нэг шинэ г сурлаа',
#  'если объявляют циклон то иностранцы бегут прочь а русские хватают фотоаппараты и бегут фотографировать',
#  'USER юлян гоу ко мне у меня целый ящик мандаринов',
#  'USER мы у себя не могем а отсель грозить шведам',
#  'USER малахов уже вторую передачу про них снял полагает видимо что людям это жутко интересно',
#  'USER USER USER USER USER USER удачной пятницы',
#  'USER нее только в мультиках USER',
#  'я похож на хипсту в гриндах чудные говнодавы обожаю эту обувь',
#  'ты тупая как валенок хотя ты не знаешь что такое валенок ты тупая как угги универ',
#  'мои любимые нас разделяет тысячи километров с хнык плак жду лето хочу приехать URL',
#  'rt USER эволюция google play d URL',
#  'а самое замечательное что в холодильнике томится джииииин',
#  'нарядили елку красотку полиграфический комплекс знак URL',
#  'USER девушку мики мауса мини не совсем это реальное животное но как есть',
#  'USER я определилась давай в бар текила на театральной тебе сколько ехать',
#  'а мы опять на хоккейчик ток на этот раз с собственным хоккеистом URL',
#  'все ровно мы самые лучшие люблю безууумно свой класс',
#  'USER после сегодняшнего мне захотелось пересмотреть тот фильм d',
#  'хочу одного такого себе домой милашки URL',
#  'USER прости дорогая это была закрытая церемония на берегу моря',
#  'USER я тоже из казани а где можно будет купить не знаешь',
#  'ну бляяяя через 8 1 серий будет хината уже знаю реакцию нс шников в японии d пака кисимото',
#  'у виксов песня хорошая понравилась очень х а вот клип я еще не видела х',
#  'в сомали деньги взвешивают а не считают наверняка и обвешивают',
#  'rt USER по моему лошадь испугалась тао d по глазам вижу d URL',
#  'USER победитель по жизни что тут сказать',
#  'USER ты то должна знать что вариант с телефоном реально работает',
#  'пришла домой выступали и в школу не пошла еху сижу хрумкаю URL',
#  'USER ахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахахаха лооооооооооооох',
#  'вот вам и красный диплом и я не на заправке а напротив любимого университета URL URL',
#  'на нг в солотчу где целыыых 5 разновидностей печенек и теплая комнатка всего за 4 рублей d',
#  'USER жаль что она не сидит в твиттере там есть слээээшик d',
#  'rt USER USER снов о диву в сны URL',
#  'напомнило приглашение от чемо d URL',
#  'rt USER кризис дубленку продает бедняга',
#  'передняя камера USER URL',
#  'кушать готовлю жду пока пожарится все URL',
#  'решение мужчины жениться последнее которое он принимает сам URL',
#  'ну вот теперь точно модная sweet home URL',
#  'не быть мне хорошим работодателем в excel посчитала зарплату получилось 15 d',
#  'USER ааа понятно з поздравь от твиттерского зз изизиз добра удачи любви зз всего всего lt зз и тебе',
#  'какой будет эта зима праздничной URL',
#  'rt USER USER да ничего удачи с уроками mtvstars justin bieber',
#  'потерла морковку помяла банан и сложила все вместе даже вкусно сейчас грызу остаток морковки',
#  'у маши петя у кристины егор у лизы рома у меня жир ахахах',
#  'rt USER USER я не помню что ругалась потом на сл день мы завтракали с папой моим ты еще в моей футболке была dd',
#  'механизатор василий петров проживающий в селе малые писюны в скотозабитом переулке дом 2 ненавидит свой адрес из за слов дом 2',
#  'USER обрати внимание на приз скорее URL',
#  'USER так значит все таки недотрах я запуталась в тебе блин',
#  'вообще я пишу сценарий я не сдержалась и сфотографировала эту идилию URL',
#  'да смысла нет абсолютно слушать так просто смотреть и все',
#  'танцовщицей в мужской клуб я тоже не пойду о follow',
#  'rt USER конь внедорожник читайменяаятебя взаимныйфолловинг teamrt2eat clubfollowback follow2gain teamfollowback htt',
#  'rt USER USER оу как мило люблю тебя',
#  'rt USER USER звук выключен нааерн d',
#  'с гордым дядей саймоном за кулисами x factor littlemix simoncowell xf photo URL',
#  'USER открою сикрит ты всигда полезное делаешь d',
#  'есть такие люди которым расскажешь что то по секрету а внутри у них нажимается мне нравится и распездеть всем',
#  'rt USER сказать что это глупо и смешно не сказать ничего ахахахах наивная наивная тей dd URL',
#  'USER позвонила ему т к у меня был трабл с интернетом он решил этот вопрос за 2 минуты эх захотелось сказать возвращайся',
#  'rt USER полечка меня прям искренне порадовала своим сообщением люблю',
#  'USER USER ты в политике',
#  'USER USER вы на самом деле идиот или просто прикидываетесь',
#  'rt USER USER а катя будет ходить в демисезонке ибо ей лень покупать на зиму что то х',
#  'да 3 вечер сериал надо какой нибудь найти и смотреть',
#  'уже затра пришла 2 ая часть с ней еще пара шмоток а также браслетик наклеечки большой календарик и журнальчик с постерами 1d',
#  'rt USER USER привет спасиииибооо',
#  'вот так вот позабавило dance 9zalov URL',
#  'rt USER USER открою сикрит ты всигда полезное делаешь d',
#  'смотреть сериалы целый день могу умею практикую dddd',
#  'смотрю на него и рука не поднимается согнать со стола котэ персик питомец nationalcatday котики кот моська URL',
#  'и учительница еще смотрит на нас улыбается загадочно ссска',
#  'USER потом еще кто нибудь полюбит енота не полюбить хуйлом быть рифмачебач',
#  'команда квн школы гейдара алиева г астрахань веселые ребята зал полон оваций URL',
#  'слава богу 2 мучительные недели в поисках сумки кончились я ее купилаааа',
#  'USER прекрасный пример он не достает лапками',
#  'так вот ты какое чудо в перьях d URL',
#  'USER эээх красивые зато мне сегодня сладко',
#  'шли всех нахуй ты прекрасна хах ок спасибо URL',
#  'соколовскийяхочутебя пригласить на пикник URL',
#  'что продлевает жизнь смех d кто же еще URL',
#  'USER рискни в рамку не эту тогда и да я готовлю блинчики d',
#  'USER спасибо считаю найти свое место очень важно',
#  'уаааа сейчас около меня прошел паренек с чисто женской походкой я прям даже не знаю как это описать но черт я ржу d',
#  'за монгол коментийн 2 оо vзэж жаахан хэрэгт дурлая',
#  'USER USER USER как же анютка любит поезда осторожнее с ирисками',
#  ...]
